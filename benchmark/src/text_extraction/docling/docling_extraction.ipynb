# %%
from docling.datamodel.base_models import InputFormat
from docling.document_converter import DocumentConverter, PdfFormatOption
from docling.datamodel.pipeline_options import PdfPipelineOptions, TableFormerMode
from docling.document_converter import DocumentConverter
import tqdm
import os
import glob

# %%
# source = "data/short_conti_annual-report-2023.pdf"
# converter = DocumentConverter()
# result = converter.convert(source)
# print(result.document.export_to_markdown())

# %%
pdfs_path = "../../data/PDF_stoxx600/test_reports"
pdfs_path = "../../data/PDF_stoxx600/more_reports"
texts_path = "../../data/TEXT_stoxx600_docling/test_reports"
texts_path = "../../data/TEXT_stoxx600_docling"

# %%
pdfs = glob.glob(pdfs_path + "/*.pdf")
pdfs
# Out:
# []

# %%
pipeline_options = PdfPipelineOptions(do_table_structure=False)
pipeline_options.table_structure_options.mode = TableFormerMode.FAST

doc_converter = DocumentConverter(
    format_options={
        InputFormat.PDF: PdfFormatOption(pipeline_options=pipeline_options)
    }
)

# %%
os.chdir("/data/resources/weichel-llama3/work/projects/nace_classification/nace_report_topic_analysis")

# %%
#for pdf in tqdm.tqdm(pdfs[1:]): 
for pdf in tqdm.tqdm(["data/datasets/reports_subset_from_full_data_3/PDFs_selected/Hanssem Co., Ltd1.pdf"]): 
    print(pdf)
    result = doc_converter.convert(pdf)
    #with open(os.path.join(texts_path, os.path.basename(pdf)[:-4])+".txt", "w") as f: 
    with open("data/datasets/reports_subset_from_full_data_3/TXTs_all/Hanssem Co., Ltd1.txt", "w") as f: 
        f.write(result.document.export_to_markdown())
# Out:
#   0%|                                                                                                                                                                                           | 0/1 [00:00<?, ?it/s]2025-12-01 08:34:12,545 - INFO - detected formats: [<InputFormat.PDF: 'pdf'>]
# data/datasets/reports_subset_from_full_data_3/PDFs_selected/Hanssem Co., Ltd1.pdf
# 2025-12-01 08:34:12,806 - INFO - Going to convert document batch...
# 2025-12-01 08:34:12,807 - INFO - Initializing pipeline for StandardPdfPipeline with options hash b9387bd18308a5f2f37220b821ce3b99
# 2025-12-01 08:34:12,862 - INFO - Loading plugin 'docling_defaults'
# 2025-12-01 08:34:12,865 - INFO - Registered picture descriptions: ['vlm', 'api']
# 2025-12-01 08:34:12,882 - INFO - Loading plugin 'docling_defaults'
# 2025-12-01 08:34:12,888 - INFO - Registered ocr engines: ['easyocr', 'ocrmac', 'rapidocr', 'tesserocr', 'tesseract']
# 2025-12-01 08:34:13,035 - INFO - Accelerator device: 'cpu'
# ...
