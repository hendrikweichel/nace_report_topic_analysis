# %%
from docling.datamodel.base_models import InputFormat
from docling.document_converter import DocumentConverter, PdfFormatOption
from docling.datamodel.pipeline_options import PdfPipelineOptions, TableFormerMode
from docling.document_converter import DocumentConverter
import tqdm
import os
import glob

# %%
# source = "data/short_conti_annual-report-2023.pdf"
# converter = DocumentConverter()
# result = converter.convert(source)
# print(result.document.export_to_markdown())

# %%
pdfs_path = "../../data/PDF_stoxx600/test_reports"
pdfs_path = "../../data/PDF_stoxx600/more_reports"
texts_path = "../../data/TEXT_stoxx600_docling/test_reports"
texts_path = "../../data/TEXT_stoxx600_docling"

# %%
pdfs = glob.glob(pdfs_path + "/*.pdf")
pdfs
# Out:
# ['../../data/PDF_stoxx600/more_reports/shell-annual-report-2022.pdf',
#  '../../data/PDF_stoxx600/more_reports/Whitbread_AR21-1.pdf',
#  '../../data/PDF_stoxx600/more_reports/Elis - 2022 financial statements.pdf',
#  '../../data/PDF_stoxx600/more_reports/kindred-group_2022.pdf',
#  '../../data/PDF_stoxx600/more_reports/subsea_2022-Annual-Report.pdf',
#  '../../data/PDF_stoxx600/more_reports/salmar-annual-report-2022.pdf']

# %%
pipeline_options = PdfPipelineOptions(do_table_structure=False)
pipeline_options.table_structure_options.mode = TableFormerMode.FAST

doc_converter = DocumentConverter(
    format_options={
        InputFormat.PDF: PdfFormatOption(pipeline_options=pipeline_options)
    }
)

# %%
for pdf in tqdm.tqdm(pdfs[1:]): 
    print(pdf)
    result = doc_converter.convert(pdf)
    with open(os.path.join(texts_path, os.path.basename(pdf)[:-4])+".txt", "w") as f: 
        f.write(result.document.export_to_markdown())
# Out:
#   0%|          | 0/5 [00:00<?, ?it/s]2025-09-30 11:40:44,185 - INFO - detected formats: [<InputFormat.PDF: 'pdf'>]
# 2025-09-30 11:40:44,244 - INFO - Going to convert document batch...
# 2025-09-30 11:40:44,250 - INFO - Initializing pipeline for StandardPdfPipeline with options hash b9387bd18308a5f2f37220b821ce3b99
# 2025-09-30 11:40:44,261 - INFO - Accelerator device: 'mps'
# ../../data/PDF_stoxx600/more_reports/Whitbread_AR21-1.pdf
# 2025-09-30 11:40:49,957 - INFO - Accelerator device: 'mps'
# 2025-09-30 11:40:53,032 - INFO - Processing document Whitbread_AR21-1.pdf
# 2025-09-30 11:45:20,501 - INFO - Finished converting document Whitbread_AR21-1.pdf in 276.36 sec.
#  20%|██        | 1/5 [04:36<18:26, 276.75s/it]2025-09-30 11:45:20,896 - INFO - detected formats: [<InputFormat.PDF: 'pdf'>]
# 2025-09-30 11:45:20,904 - INFO - Going to convert document batch...
# 2025-09-30 11:45:20,906 - INFO - Processing document Elis - 2022 financial statements.pdf
# ../../data/PDF_stoxx600/more_reports/Elis - 2022 financial statements.pdf
# 2025-09-30 11:46:13,136 - INFO - Finished converting document Elis - 2022 financial statements.pdf in 52.25 sec.
#  40%|████      | 2/5 [05:29<07:14, 144.87s/it]2025-09-30 11:46:13,450 - INFO - detected formats: [<InputFormat.PDF: 'pdf'>]
# 2025-09-30 11:46:13,456 - INFO - Going to convert document batch...
# 2025-09-30 11:46:13,457 - INFO - Processing document kindred-group_2022.pdf
# ../../data/PDF_stoxx600/more_reports/kindred-group_2022.pdf
# 2025-09-30 11:55:14,139 - INFO - Finished converting document kindred-group_2022.pdf in 540.69 sec.
#  60%|██████    | 3/5 [14:30<10:51, 325.80s/it]2025-09-30 11:55:14,596 - INFO - detected formats: [<InputFormat.PDF: 'pdf'>]
# 2025-09-30 11:55:14,642 - INFO - Going to convert document batch...
# 2025-09-30 11:55:14,647 - INFO - Processing document subsea_2022-Annual-Report.pdf
# ../../data/PDF_stoxx600/more_reports/subsea_2022-Annual-Report.pdf
# 2025-09-30 12:09:48,531 - INFO - Finished converting document subsea_2022-Annual-Report.pdf in 873.97 sec.
#  80%|████████  | 4/5 [29:04<09:02, 542.34s/it]2025-09-30 12:09:48,851 - INFO - detected formats: [<InputFormat.PDF: 'pdf'>]
# 2025-09-30 12:09:48,878 - INFO - Going to convert document batch...
# 2025-09-30 12:09:48,880 - INFO - Processing document salmar-annual-report-2022.pdf
# ../../data/PDF_stoxx600/more_reports/salmar-annual-report-2022.pdf
# 2025-09-30 12:26:38,975 - INFO - Finished converting document salmar-annual-report-2022.pdf in 1010.11 sec.
# 100%|██████████| 5/5 [45:55<00:00, 551.07s/it]
