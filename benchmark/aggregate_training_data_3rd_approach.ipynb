# %% [markdown]
# # Aggregate Training data for BERT
#
# 1. Apply approach 1
# 2. Select those paragraphs that are classified as relevant by the relevancy classifier

# %%
import pandas as pd
import glob
import os
import tqdm
import sys
import numpy as np
import matplotlib.pyplot as plt
sys.path.append("..")

wor_dir = "/data/resources/weichel-llama3/work/projects/nace_classification/nace_report_topic_analysis"
os.chdir(wor_dir)
from test_base import *
from BERT_classifier.Classify_report_with_BERT import classification_report_BERT

# %% [markdown]
# ### Load Data

# %%
overview_path = "/Users/hendrikweichel/projects/NaceCodeClassification/nace_report_topic_analysis_3/data/datasets/reports_subset_from_full_data_1/reports_subset_from_full_data_1_overview.csv"
overview_path = "/Users/hendrikweichel/projects/NaceCodeClassification/nace_report_topic_analysis_3/data/datasets/stoxx_600/stoxx_600_overview.csv"
overview_path = "/Users/hendrikweichel/projects/NaceCodeClassification/nace_report_topic_analysis_3/data/datasets/reports_subset_from_full_data_1/reports_subset_from_full_data_1_overview.csv"
overview_path = wor_dir + "/data/datasets/reports_subset_from_full_data_1/reports_subset_from_full_data_1_overview.csv"
overview_path = wor_dir + "/data/datasets/reports_subset_from_full_data_2/reports_subset_from_full_data_2_overview.csv"

# %%
raw_data_path = "/Users/hendrikweichel/projects/NaceCodeClassification/nace_report_topic_analysis_3/results/paragraph_and_sentence_len_3_min_chunk_len_100_cos_thresh_0.4_nace_level_2_stoxx/"
raw_data_path = "/Users/hendrikweichel/projects/NaceCodeClassification/nace_report_topic_analysis_3/results/paragraph_and_sentence_len_3_min_chunk_len_100_cos_thresh_0.4_nace_level_2_stoxx/"
raw_data_path = "/Users/hendrikweichel/projects/NaceCodeClassification/nace_report_topic_analysis_3/results/paragraph_and_sentence_len_3_min_chunk_len_0_cos_thresh_0.4_nace_level_1_stoxx/"
raw_data_path = "/Users/hendrikweichel/projects/NaceCodeClassification/nace_report_topic_analysis_3/results/tables_cos_sim_0.0_nace_level_1_stoxx/"
raw_data_path = "/Users/hendrikweichel/projects/NaceCodeClassification/nace_report_topic_analysis_3/results/sentence_len_5/paragraph_and_sentence_len_5_min_chunk_len_100_cos_thresh_0.4_nace_level_2_stoxx/"
raw_data_path = "/Users/hendrikweichel/projects/NaceCodeClassification/nace_report_topic_analysis_3/results/sentence_len_5/paragraph_and_sentence_len_5_min_chunk_len_100_cos_thresh_0.4_nace_level_1_stoxx/"
raw_data_path = "/Users/hendrikweichel/projects/NaceCodeClassification/nace_report_topic_analysis_3/results/paragraph_and_sentence_len_6_min_chunk_len_100_cos_thresh_0.4_nace_level_1_stoxx/"
raw_data_path = "/Users/hendrikweichel/projects/NaceCodeClassification/nace_report_topic_analysis_3/results/dataset__reports_subset_from_full_data_1_sentence_len_6__min_chunk_len_100__cos_thresh_0.4__nace_level_1/"
raw_data_path = "/Users/hendrikweichel/projects/NaceCodeClassification/nace_report_topic_analysis_3/results/dataset__reports_subset_from_full_data_1_sentence_len_6__min_chunk_len_100__cos_thresh_0.4__nace_level_2/"
raw_data_path = "/Users/hendrikweichel/projects/NaceCodeClassification/nace_report_topic_analysis_3/results/dataset__reports_subset_from_full_data_1_sentence_len_6__min_chunk_len_100__cos_thresh_0.4__nace_level_4/"

raw_data_path = "/Users/hendrikweichel/projects/NaceCodeClassification/nace_report_topic_analysis_3/results/dataset__reports_subset_from_full_data_1_sentence_len_6__min_chunk_len_100__cos_thresh_0.4__nace_level_1/"
raw_data_path = "/Users/hendrikweichel/projects/NaceCodeClassification/nace_report_topic_analysis_3/results/dataset__reports_subset_from_full_data_1_sentence_len_6__min_chunk_len_100__cos_thresh_0.4__nace_level_2/"
raw_data_path = wor_dir + "/results/dataset__reports_subset_from_full_data_1_sentence_len_6__min_chunk_len_100__cos_thresh_0.4__nace_level_4/"
raw_data_path = "/Users/hendrikweichel/projects/NaceCodeClassification/nace_report_topic_analysis_3/results/dataset__reports_subset_from_full_data_1_sentence_len_6__min_chunk_len_100__cos_thresh_0.4__nace_level_3_1/"
raw_data_path = wor_dir + "/results/dataset__reports_subset_from_full_data_1_sentence_len_6__min_chunk_len_100__cos_thresh_0.4__nace_level_1/"
raw_data_path = wor_dir + "/results/dataset__reports_subset_from_full_data_2_sentence_len_6__min_chunk_len_100__cos_thresh_0.4__nace_level_1/"

# %%
reports = glob.glob(raw_data_path + "*/*_short.csv")
reports = glob.glob(raw_data_path + "*/*_long.csv")
len(reports)
# Out:
# 3053

# %%
sample_ratio = 1

# %%
max_elements_per_class = 1000000

top_k_sentences = 200000

# %%
# if true, adds only chunks to training that have been classified into the same NACE class its report comes from
filter_only_right_chunks = True

# %%
# if true, adds random chunks that do not fulfill the minimum treshold (for BERT Training)
with_null_classifiers = True

# %%
new_threshold_cos_sin = 0.4

# %%
nace_level_descriptions = 1
nace_level = 1
assert nace_level_descriptions >= nace_level

# %%
training_data_path = "data/training_data/approach_3"

# %%
suffix = f"sample_ratio_{sample_ratio}" + ("__filter_only_right_chunks" if filter_only_right_chunks else "") + ("__with_null_classifiers" if with_null_classifiers else "") + f"__nace_level_{nace_level}" + f"__cos_thres_{new_threshold_cos_sin}"

# "_subsample" if sample_ratio != 1 else ""
# end_path = os.path.join("/Users/hendrikweichel/projects/NaceCodeClassification/nace_report_topic_analysis_3/data/test_read_training_data_right_classifications", raw_data_path.split("/")[-2] + suffix)
# end_path = os.path.join("/Users/hendrikweichel/projects/NaceCodeClassification/nace_report_topic_analysis_3/data/test_read_training_data", raw_data_path.split("/")[-2] + suffix + "_with_no_class__cos_sim_04")
# end_path = os.path.join("/Users/hendrikweichel/projects/NaceCodeClassification/nace_report_topic_analysis_3/data/test_read_training_data_right_classifications", raw_data_path.split("/")[-2] + suffix + "_with_no_class__cos_sim_04")

end_path = os.path.join(training_data_path, 
                        raw_data_path.split("/")[-2] + "__" + suffix)
end_path
# Out:
# 'data/training_data/approach_3/dataset__reports_subset_from_full_data_2_sentence_len_6__min_chunk_len_100__cos_thresh_0.4__nace_level_1__sample_ratio_1__filter_only_right_chunks__with_null_classifiers__nace_level_1__cos_thres_0.4'

# %%
#df_overview = pd.read_excel(overview_path)
df_overview = pd.read_csv(overview_path)
df_overview
# Out:
#       Unnamed: 0        Symbol                                      Name  \
# 0              0  CA05335P1099                 Auxly Cannabis Group Inc.
# 1              1  JP3947800003              MEGMILK SNOW BRAND Co., Ltd.
# 2              2  ID1000167901  PT Cilacap Samudera Fishing Industry Tbk
# 3              3  JP3843250006                        Hokuto Corporation
# 4              4  VN000000VTQ6      Viet Trung Quang Binh Joint Stock Co
# ...          ...           ...                                       ...
# 3274        5783  US0404432025                    Aristocrat Group Corp.
# 3275       73228  KYG816BW1095                   Sino-Life Group Limited
# 3276       86319  KYG9477E1070                 Water Oasis Group Limited
# 3277       66027  US76119X1054                     Reservoir Media, Inc.
# 3278       38190  KYG4707P1054       Icon Culture Global Company Limited
#
#       Company is Active  Company Founded Date Country of Primary Listing Iso3  \
# 0                     1                1987.0                             CAN
# 1                     1                2009.0                             JPN
# 2                     0                1999.0                             IDN
# 3                     1                1964.0                             JPN
# 4                     0                1961.0                             VNM
# ...                 ...                   ...                             ...
# 3274                  0                2011.0                             USA
# 3275                  1                2005.0                             HKG
# 3276                  1                1998.0                             HKG
# 3277                  1                2007.0                             USA
# 3278                  1                2019.0                             HKG
#
#           CUSIP  Date Of First Trade Entity Country HQ Entity Credit Parent  \
# 0     05335P109           19960301.0               CAN             003V9K-E
# 1     J41966102           20220727.0               JPN             0833Y1-E
# 2     Y129H6108           20220527.0               IDN                  @NA
# 3     J2224T102           19941202.0               JPN             05HY7N-E
# 4     Y937XS108                  NaN               VNM                  @NA
# ...         ...                  ...               ...                  ...
# 3274  040443202           20120313.0               USA             00DDP9-E
# 3275  G816BW109           20090909.0               HKG             00C60C-E
# 3276  G9477E107           20070905.0               HKG             00610B-E
# 3277  76119X105           20210105.0               USA             0NVYZ2-E
# 3278  G4707P105           20200114.0               CHN                  @NA
#
#       ...          ISIN Primary Equity Listing  \
# 0     ...  CA05335P1099                 BDGMQB
# 1     ...  JP3947800003                 B3ZC07
# 2     ...  ID1000167901                 BMBMZG
# 3     ...  JP3843250006                 643271
# 4     ...  VN000000VTQ6                 BMCR2W
# ...   ...           ...                    ...
# 3274  ...  US0404432025               04044320
# 3275  ...  KYG816BW1095                 B409GR
# 3276  ...  KYG9477E1070                 651233
# 3277  ...  US76119X1054               76119X10
# 3278  ...  KYG4707P1054                 BJYFY1
#
#                                    Proper Name Public Company Region Ticker  \
# 0                    Auxly Cannabis Group Inc.            1.0        XLY-CA
# 1                 MEGMILK SNOW BRAND Co., Ltd.            1.0      MMSBF-US
# 2     PT Cilacap Samudera Fishing Industry Tbk            1.0       ASHA-ID
# 3                           Hokuto Corporation            1.0       1379-JP
# 4         Viet Trung Quang Binh Joint Stock Co            1.0        VTQ-VN
# ...                                        ...            ...           ...
# 3274                    Aristocrat Group Corp.            1.0       ASCC-US
# 3275                   Sino-Life Group Limited            1.0       8296-HK
# 3276                 Water Oasis Group Limited            1.0      WOSSF-US
# 3277                     Reservoir Media, Inc.            1.0       RSVR-US
# 3278       Icon Culture Global Company Limited            1.0       8500-HK
#
#      Sec is Primary Issue  Sec Type    SEDOL  NACE_letter  \
# 0                       1     SHARE  BDGMQB3            A
# 1                       0     SHARE  BKQN701            A
# 2                       0     SHARE  BMBMZG9            A
# 3                       1     SHARE  6432715            A
# 4                       0     SHARE  BMCR2W8            A
# ...                   ...       ...      ...          ...
# 3274                    1     SHARE  BWX6257            S
# 3275                    1     SHARE  B409GR3            S
# 3276                    0     SHARE  B02V9Q9            S
# 3277                    1     SHARE  BP0B9H7            S
# 3278                    1     SHARE  BJYFY12            T
#
#                                              Report
# 0                    Auxly Cannabis Group Inc.2.pdf
# 1                 MEGMILK SNOW BRAND Co., Ltd.2.pdf
# 2     PT Cilacap Samudera Fishing Industry Tbk3.pdf
# 3                           Hokuto Corporation1.pdf
# 4         Viet Trung Quang Binh Joint Stock Co3.pdf
# ...                                             ...
# 3274                    Aristocrat Group Corp.1.pdf
# 3275                   Sino-Life Group Limited1.pdf
# 3276                 Water Oasis Group Limited1.pdf
# 3277                     Reservoir Media, Inc.1.pdf
# 3278       Icon Culture Global Company Limited2.pdf
#
# [3279 rows x 23 columns]

# %%
df_nace_codes_descriptions = pd.read_csv("data/NACE_Rev2_Structure_Explanatory_Notes_EN__1_.tsv", sep="\t")
filter_level_1_classes = "ABCDEFGHIJKLMNOPQRSTUVW"

# %% [markdown]
# ### Create Dataset

# %%
result = pd.DataFrame(columns=["Sentences", "Score", "NACE_Code"])

# loop over all reports and get the all the sentences 
for report in tqdm.tqdm(reports):

    df = pd.read_csv(report)

    if filter_only_right_chunks: 
        report_name = os.path.basename(report).replace(".txt_long.csv", "") + ".pdf"
        report_code = df_overview[df_overview["Report"]==report_name]["NACE"].iloc[0]
        report_code = get_all_level(report_code)[nace_level]
        if nace_level == nace_level_descriptions: 
            filter_column = list(filter(lambda x: "Scores_"+str(report_code) in x, df.columns))
        else:
            filter_column = []
            for column in df.columns: 
                if "Scores" in column: 
                    if get_all_level(column.split("_")[1])[nace_level]==report_code: 
                        filter_column.append(column)
        df = df[["Sentences"]+filter_column]

    if nace_level == 1: 
        # filter some nace classes
        scores = df[[column for column in df.columns if ("Scores" in column) and get_all_level(column.split("_")[1], df_nace_codes_descriptions)[nace_level] in filter_level_1_classes]].columns
    else: 
        scores = df[[column for column in df.columns if ("Scores" in column)]].columns
    
    for score in scores:
        temp = df[df[score].notna()][["Sentences", score]]  
        try: 
            temp["NACE_Code"] = get_all_level(score.split("_")[1])[nace_level]
        except IndexError: 
            continue
        temp = temp.rename(columns={score: "Score"})
        result = pd.concat([result, temp])
# Out:
#   0%|                                                                                                                                                                                        | 0/3053 [00:00<?, ?it/s]/tmp/ipykernel_220801/32301125.py:35: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   result = pd.concat([result, temp])
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 3053/3053 [01:39<00:00, 30.54it/s]

# %%
os.makedirs(end_path, exist_ok=True)

# %%
recordings = []

# %%
# for each code, store the 100 with the highest similarity score to the code

full_df = []
for code in tqdm.tqdm(set(result["NACE_Code"].to_list())): 

    #if not get_all_level(code.split("_")[1], df_nace_codes_descriptions)[1] in filter_level_1_classes: 
    # if not get_all_level(code, df_nace_codes_descriptions)[nace_level] in filter_level_1_classes: 
    #     continue

    temp = result[result["NACE_Code"] == code]
    temp = temp.drop_duplicates(subset="Sentences")
    temp = temp[temp["Sentences"].apply(len) >= 100]
    temp = temp.sort_values(by="Score", ascending=False)

    if with_null_classifiers: 
        temp.loc[temp["Score"]<new_threshold_cos_sin, "NACE_Code"] = "NO_CLASS"
        temp = temp[(temp["Score"] >= new_threshold_cos_sin) | (temp["NACE_Code"]=="NO_CLASS")]
        
        class_index = temp[temp["NACE_Code"]!="NO_CLASS"].index
        no_class_index = temp[temp["NACE_Code"]=="NO_CLASS"].index

        # print(len(temp[temp["NACE_Code"]=="NO_CLASS"]))
        # print(temp[temp["NACE_Code"]=="NO_CLASS"].index)
        # print(temp.loc[no_class_index])
        # print(code)
        # print("--")

        temp = temp.loc[list(np.random.choice(no_class_index, len(class_index)))+list(class_index)]
    else:
        temp = temp[temp["Score"] >= new_threshold_cos_sin]

    number_of_elements_per_class = min(int(sample_ratio*len(temp)), max_elements_per_class, len(temp))
    random_choice = np.random.choice(len(temp), number_of_elements_per_class, replace=False)
    temp = temp.iloc[random_choice]
    temp = temp.sort_values(by="Score", ascending=False)
    temp = temp.iloc[:top_k_sentences, :]
    temp = temp.reset_index(drop=True)
    temp["Evaluation"] = None
    temp["Notes"] = None
    temp = temp[["Evaluation", "Notes", "Sentences", "Score", "NACE_Code"]]

    recordings.append({"Code": code,"Nbr. of Chunks": len(temp),"Avg. Length": temp["Sentences"].apply(len).mean(), "Avg. Score": temp["Score"].mean(), "Min. Score": temp["Score"].min(), "Max. Score": temp["Score"].max()})

    text = ""
    for i, row in temp.iterrows():
        text += f"#{i}, Score: " + str(round(row["Score"], 2)) + "\n\n" + row["Sentences"] + "\n\n"

    with open(os.path.join(end_path, code.replace("/"," ")) + ".txt", "w") as f:
        f.write(text)
    
    temp = temp.drop_duplicates(subset=["Sentences"])
    temp.to_csv(os.path.join(end_path, code.replace("/"," ")) + ".csv")

    full_df.append(temp)

full_df = pd.concat(full_df, axis=0, ignore_index=True)
# Out:
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 19/19 [02:27<00:00,  7.76s/it]

# %%
statistics = full_df.groupby("NACE_Code").agg({"Sentences": "count", "Score": "mean"})

# %%
full_df = pd.concat([
    full_df[full_df["NACE_Code"] == "NO_CLASS"].sample(statistics.loc[statistics.index != "NO_CLASS", "Sentences"].max()), 
    full_df[full_df["NACE_Code"] != "NO_CLASS"]
    ])

# %%
statistics_full_df = full_df.groupby("NACE_Code").agg({"Sentences": "count", "Score": "mean"})
statistics_full_df.to_csv(end_path + "/statistics.csv")

# %%
statistics_full_df
# Out:
#            Sentences     Score
# NACE_Code
# A               1699  0.440107
# B               9474  0.457949
# C               3741  0.445098
# D              13358  0.453545
# E               5454  0.470569
# F              11691  0.473447
# G               9010  0.440229
# H              11817  0.452148
# I               3938  0.441540
# J               1936  0.448265
# K              34928  0.452334
# L              11745  0.448449
# M               2945  0.440599
# N               5493  0.430943
# NO_CLASS       34928  0.265664
# P               1869  0.450086
# Q               1163  0.442785
# R                351  0.443788
# S                712  0.428798
# T                 30  0.445547

# %%
full_df = full_df.rename(columns={"Sentences": "text"})
#full_df = full_df.drop(columns="Score")
full_df
# Out:
#        Evaluation Notes                                               text  \
# 218423       None  None  improve efficiency at the most energy intensiv...
# 526617       None  None  cash and cash equivalents shortterm investment...
# 402677       None  None  capital to risk weighted assets ratio crar cap...
# 402554       None  None  operating segments are reported in a manner co...
# 267576       None  None  in revenue from the heat and power company was...
# ...           ...   ...                                                ...
# 672058       None  None  areas of significant judgement and estimation ...
# 672059       None  None  gross profit selling general and administrativ...
# 672060       None  None  information on segment assets and liabilities ...
# 672061       None  None  as management services revenue accounted for m...
# 672062       None  None  the groups contract assets represent the group...
#
#            Score NACE_Code
# 218423  0.373630  NO_CLASS
# 526617  0.209834  NO_CLASS
# 402677  0.194316  NO_CLASS
# 402554  0.194814  NO_CLASS
# 267576  0.292308  NO_CLASS
# ...          ...       ...
# 672058  0.400034         N
# 672059  0.400026         N
# 672060  0.400011         N
# 672061  0.400007         N
# 672062  0.400007         N
#
# [166282 rows x 5 columns]

# %% [markdown]
# ### Apply relevancy model

# %%
full_df["relevancy_score"] = [classification_report_BERT.relevancy_classification(text) for text in tqdm.tqdm(full_df["text"])]
# Out:
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 166282/166282 [1:29:28<00:00, 30.97it/s]

# %%
# filter df
threshold_relevancy = classification_report_BERT.get_treshold_relevancy_model()
full_df["relevant"] = full_df["relevancy_score"] > threshold_relevancy
full_df_relevant = full_df[full_df["relevant"]]

# %%
threshold_relevancy
# Out:
# 0.31

# %%
full_df["relevant"].mean()
# Out:
# 0.09922300669946237

# %%
full_df["relevancy_score"].min()
# Out:
# 0.04585384950041771

# %%
full_df
# Out:
#        Evaluation Notes                                               text  \
# 218423       None  None  improve efficiency at the most energy intensiv...
# 526617       None  None  cash and cash equivalents shortterm investment...
# 402677       None  None  capital to risk weighted assets ratio crar cap...
# 402554       None  None  operating segments are reported in a manner co...
# 267576       None  None  in revenue from the heat and power company was...
# ...           ...   ...                                                ...
# 672058       None  None  areas of significant judgement and estimation ...
# 672059       None  None  gross profit selling general and administrativ...
# 672060       None  None  information on segment assets and liabilities ...
# 672061       None  None  as management services revenue accounted for m...
# 672062       None  None  the groups contract assets represent the group...
#
#            Score NACE_Code  relevancy_score  relevant
# 218423  0.373630  NO_CLASS         0.048819     False
# 526617  0.209834  NO_CLASS         0.046366     False
# 402677  0.194316  NO_CLASS         0.046711     False
# 402554  0.194814  NO_CLASS         0.049357     False
# 267576  0.292308  NO_CLASS         0.047097     False
# ...          ...       ...              ...       ...
# 672058  0.400034         N         0.047707     False
# 672059  0.400026         N         0.047575     False
# 672060  0.400011         N         0.047264     False
# 672061  0.400007         N         0.047851     False
# 672062  0.400007         N         0.047176     False
#
# [166282 rows x 7 columns]

# %%
statistics = full_df_relevant.groupby("NACE_Code").agg({"text": "count", "Score": "mean"})
statistics["text_diff_to_full_df"] = statistics["text"] - statistics_full_df["Sentences"]
statistics["text_share_of_full_df"] = statistics["text"] / statistics_full_df["Sentences"]
statistics["score_diff_to_full_df"] = statistics["Score"] - statistics_full_df["Score"]
statistics
# Out:
#            text     Score  text_diff_to_full_df  text_share_of_full_df  \
# NACE_Code
# A           273  0.444787                 -1426               0.160683
# B           596  0.450914                 -8878               0.062909
# C           434  0.443975                 -3307               0.116012
# D          1274  0.457475                -12084               0.095374
# E           779  0.475324                 -4675               0.142831
# F          1341  0.480063                -10350               0.114704
# G           726  0.446331                 -8284               0.080577
# H          1626  0.464716                -10191               0.137598
# I           953  0.447322                 -2985               0.242001
# J           241  0.447747                 -1695               0.124483
# K          1524  0.449535                -33404               0.043633
# L           797  0.454492                -10948               0.067859
# M          1149  0.445132                 -1796               0.390153
# N           435  0.437217                 -5058               0.079192
# NO_CLASS   3328  0.274373                -31600               0.095282
# P           293  0.448298                 -1576               0.156768
# Q           482  0.445288                  -681               0.414445
# R           199  0.448741                  -152               0.566952
# S            47  0.445873                  -665               0.066011
# T             2  0.444389                   -28               0.066667
#
#            score_diff_to_full_df
# NACE_Code
# A                       0.004680
# B                      -0.007035
# C                      -0.001123
# D                       0.003930
# E                       0.004756
# F                       0.006616
# G                       0.006102
# H                       0.012568
# I                       0.005782
# J                      -0.000518
# K                      -0.002800
# L                       0.006044
# M                       0.004533
# N                       0.006274
# NO_CLASS                0.008709
# P                      -0.001788
# Q                       0.002502
# R                       0.004953
# S                       0.017076
# T                      -0.001159

# %% [markdown]
# ### Store

# %%
from sklearn.model_selection import train_test_split

# Split full_df_relevant into train (60%) and temp (40%)
train_df, temp_df = train_test_split(full_df_relevant, test_size=0.4, random_state=42)

# Split temp into test (20%) and validation (20%)
test_df, val_df = train_test_split(temp_df, test_size=0.5, random_state=42)

# Print the sizes of each split
print(f"Train size: {len(train_df)}, Test size: {len(test_df)}, Validation size: {len(val_df)}")
# Out:
# Train size: 9899, Test size: 3300, Validation size: 3300

# %%
statistics.to_csv(end_path + "/statistics.csv")

# %%
statistics
# Out:
#            text     Score  text_diff_to_full_df  text_share_of_full_df  \
# NACE_Code
# A           273  0.444787                 -1426               0.160683
# B           596  0.450914                 -8878               0.062909
# C           434  0.443975                 -3307               0.116012
# D          1274  0.457475                -12084               0.095374
# E           779  0.475324                 -4675               0.142831
# F          1341  0.480063                -10350               0.114704
# G           726  0.446331                 -8284               0.080577
# H          1626  0.464716                -10191               0.137598
# I           953  0.447322                 -2985               0.242001
# J           241  0.447747                 -1695               0.124483
# K          1524  0.449535                -33404               0.043633
# L           797  0.454492                -10948               0.067859
# M          1149  0.445132                 -1796               0.390153
# N           435  0.437217                 -5058               0.079192
# NO_CLASS   3328  0.274373                -31600               0.095282
# P           293  0.448298                 -1576               0.156768
# Q           482  0.445288                  -681               0.414445
# R           199  0.448741                  -152               0.566952
# S            47  0.445873                  -665               0.066011
# T             2  0.444389                   -28               0.066667
#
#            score_diff_to_full_df
# NACE_Code
# A                       0.004680
# B                      -0.007035
# C                      -0.001123
# D                       0.003930
# E                       0.004756
# F                       0.006616
# G                       0.006102
# H                       0.012568
# I                       0.005782
# J                      -0.000518
# K                      -0.002800
# L                       0.006044
# M                       0.004533
# N                       0.006274
# NO_CLASS                0.008709
# P                      -0.001788
# Q                       0.002502
# R                       0.004953
# S                       0.017076
# T                      -0.001159

# %%
full_df_relevant.to_csv(end_path + "/full_data.csv", index=False)
full_df.to_csv(end_path + "/full_data_with_relevancy.csv", index=False)

# %%
train_df.to_csv(end_path + "/train_data.csv", index=False)
val_df.to_csv(end_path + "/val_data.csv", index=False)
test_df.to_csv(end_path + "/test_data.csv", index=False)

# %%
end_path
# Out:
# 'data/training_data/approach_3/dataset__reports_subset_from_full_data_2_sentence_len_6__min_chunk_len_100__cos_thresh_0.4__nace_level_1__sample_ratio_1__filter_only_right_chunks__with_null_classifiers__nace_level_1__cos_thres_0.4'

# %%
# %pwd
# Out:
# '/data/resources/weichel-llama3/work/projects/nace_classification/nace_report_topic_analysis'
