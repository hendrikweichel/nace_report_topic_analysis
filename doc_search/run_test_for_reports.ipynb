# %%
from langchain_openai import OpenAI
from langchain_ollama import OllamaLLM
import prompts
import schemas
import json
from langchain_core.output_parsers import JsonOutputParser
import pandas as pd
from tqdm import tqdm
from langchain_core.prompts import PromptTemplate
import re
import glob
import os

# %%
with open("questions.json", "r") as f: 
    questions_json = json.load(f)

# %%
end_path = "data/results/"

# %%
reports_path = "data/TXTs copy"

# %%
report_paths = glob.glob(reports_path + "/*.json")

# %%
# Function to get a language model object (Ollama or ChatGPT)
def get_language_model(model_type: str = "ollama", model_name: str = "default-model"):
    """
    Returns a language model object (Ollama or ChatGPT).
    
    Args:
        model_type (str): The type of model to use ("ollama" or "chatgpt"). Default is "ollama".
        model_name (str): The name of the model to use. Default is "default-model".
    
    Returns:
        An instance of the selected language model.
    """
    if model_type.lower() == "ollama":
        return OllamaLLM(model=model_name)
    elif model_type.lower() == "chatgpt":
        return OpenAI(model=model_name)
    else:
        raise ValueError("Invalid model_type. Choose 'ollama' or 'chatgpt'.")

# Function to interact with thea language model
def query_llm(llm, question: str, page: str):
    """
    Queries the language model with a question and a page string.
    
    Args:
        llm: The language model object.
        question (str): The question to ask the model.
        page (str): The page string to provide context.
    
    Returns:
        str: The output of the language model.
    """
    prompt = f"Context: {page}\n\nQuestion: {question}"
    return llm.invoke(prompt)

# %%
llm = get_language_model(model_name="llama3:8b")
parser = JsonOutputParser()

# %%
# results = []

# for page in tqdm(report["pages"]): 
#     prompt = prompts.render_prompt(
#             questions_[0],
#             page["markdown"],
#             prompt_template_id="baseline",
#             few_shot=False,
#             truncate_at=None,
#         )

#     llm_response = llm.invoke(prompt.text)

#     match = re.search(r"\{.*\}", llm_response, re.DOTALL)
#     if not match:
#         print(llm_response)
#         #raise ValueError("No JSON found in LLM output!")
    

#     json_str = match.group(0)

#     parsed = parser.parse(json_str)

#     result_page = parsed
#     result_page["page"] = page["page"]
#     result_page["markdown"] = page["markdown"]
#     results.append(result_page)

# df = pd.DataFrame(results)

# %%
questions = [schemas.QuestionSpec(**q) for q in questions_json][1:2]
questions
# Out:
# [QuestionSpec(id='DP2_scope12', question='Are the scope 1 and 2 emission reported?', include=[], exclude=[], prompt_template_id='baseline', few_shot_examples=[])]

# %%
for report_path in tqdm(report_paths): 

    with open(report_path, "r") as f: 
        report = json.load(f)

    report_result_path = os.path.join(end_path, os.path.basename(report_path))
    os.makedirs(report_result_path, exist_ok =True)

    for question in questions: 
        results = []
        for page in tqdm(report["pages"]): 
            prompt = prompts.render_prompt(
                    question,
                    page["markdown"],
                    prompt_template_id="baseline",
                    few_shot=False,
                    truncate_at=None,
                )

            llm_response = llm.invoke(prompt.text)

            match = re.search(r"\{.*\}", llm_response, re.DOTALL)
            if match:
                json_str = match.group(0)

                parsed = parser.parse(json_str)

                result_page = parsed
                result_page["page"] = page["page"]
                result_page["markdown"] = page["markdown"]
                results.append(result_page)

        df = pd.DataFrame(results)
        df.to_csv(os.path.join(report_result_path, f"{question.id}"))
# Out:
#   0%|          | 0/15 [00:00<?, ?it/s]
# id='DP2_scope12' question='Are the scope 1 and 2 emission reported?' include=[] exclude=[] prompt_template_id='baseline' few_shot_examples=[]
# id='DP2_scope12' question='Are the scope 1 and 2 emission reported?' include=[] exclude=[] prompt_template_id='baseline' few_shot_examples=[]
# id='DP2_scope12' question='Are the scope 1 and 2 emission reported?' include=[] exclude=[] prompt_template_id='baseline' few_shot_examples=[]
# id='DP2_scope12' question='Are the scope 1 and 2 emission reported?' include=[] exclude=[] prompt_template_id='baseline' few_shot_examples=[]
# id='DP2_scope12' question='Are the scope 1 and 2 emission reported?' include=[] exclude=[] prompt_template_id='baseline' few_shot_examples=[]
# id='DP2_scope12' question='Are the scope 1 and 2 emission reported?' include=[] exclude=[] prompt_template_id='baseline' few_shot_examples=[]
# id='DP2_scope12' question='Are the scope 1 and 2 emission reported?' include=[] exclude=[] prompt_template_id='baseline' few_shot_examples=[]
# id='DP2_scope12' question='Are the scope 1 and 2 emission reported?' include=[] exclude=[] prompt_template_id='baseline' few_shot_examples=[]
# id='DP2_scope12' question='Are the scope 1 and 2 emission reported?' include=[] exclude=[] prompt_template_id='baseline' few_shot_examples=[]
# id='DP2_scope12' question='Are the scope 1 and 2 emission reported?' include=[] exclude=[] prompt_template_id='baseline' few_shot_examples=[]
# id='DP2_scope12' question='Are the scope 1 and 2 emission reported?' include=[] exclude=[] prompt_template_id='baseline' few_shot_examples=[]
# id='DP2_scope12' question='Are the scope 1 and 2 emission reported?' include=[] exclude=[] prompt_template_id='baseline' few_shot_examples=[]
# id='DP2_scope12' question='Are the scope 1 and 2 emission reported?' include=[] exclude=[] prompt_template_id='baseline' few_shot_examples=[]
# id='DP2_scope12' question='Are the scope 1 and 2 emission reported?' include=[] exclude=[] prompt_template_id='baseline' few_shot_examples=[]
# id='DP2_scope12' question='Are the scope 1 and 2 emission reported?' include=[] exclude=[] prompt_template_id='baseline' few_shot_examples=[]
# id='DP2_scope12' question='Are the scope 1 and 2 emission reported?' include=[] exclude=[] prompt_template_id='baseline' few_shot_examples=[]
# id='DP2_scope12' question='Are the scope 1 and 2 emission reported?' include=[] exclude=[] prompt_template_id='baseline' few_shot_examples=[]
# id='DP2_scope12' question='Are the scope 1 and 2 emission reported?' include=[] exclude=[] prompt_template_id='baseline' few_shot_examples=[]
# id='DP2_scope12' question='Are the scope 1 and 2 emission reported?' include=[] exclude=[] prompt_template_id='baseline' few_shot_examples=[]
# id='DP2_scope12' question='Are the scope 1 and 2 emission reported?' include=[] exclude=[] prompt_template_id='baseline' few_shot_examples=[]
# id='DP2_scope12' question='Are the scope 1 and 2 emission reported?' include=[] exclude=[] prompt_template_id='baseline' few_shot_examples=[]
# id='DP2_scope12' question='Are the scope 1 and 2 emission reported?' include=[] exclude=[] prompt_template_id='baseline' few_shot_examples=[]
# id='DP2_scope12' question='Are the scope 1 and 2 emission reported?' include=[] exclude=[] prompt_template_id='baseline' few_shot_examples=[]
# id='DP2_scope12' question='Are the scope 1 and 2 emission reported?' include=[] exclude=[] prompt_template_id='baseline' few_shot_examples=[]
# id='DP2_scope12' question='Are the scope 1 and 2 emission reported?' include=[] exclude=[] prompt_template_id='baseline' few_shot_examples=[]
# id='DP2_scope12' question='Are the scope 1 and 2 emission reported?' include=[] exclude=[] prompt_template_id='baseline' few_shot_examples=[]
# id='DP2_scope12' question='Are the scope 1 and 2 emission reported?' include=[] exclude=[] prompt_template_id='baseline' few_shot_examples=[]
# id='DP2_scope12' question='Are the scope 1 and 2 emission reported?' include=[] exclude=[] prompt_template_id='baseline' few_shot_examples=[]
# id='DP2_scope12' question='Are the scope 1 and 2 emission reported?' include=[] exclude=[] prompt_template_id='baseline' few_shot_examples=[]
# id='DP2_scope12' question='Are the scope 1 and 2 emission reported?' include=[] exclude=[] prompt_template_id='baseline' few_shot_examples=[]
# id='DP2_scope12' question='Are the scope 1 and 2 emission reported?' include=[] exclude=[] prompt_template_id='baseline' few_shot_examples=[]
# id='DP2_scope12' question='Are the scope 1 and 2 emission reported?' include=[] exclude=[] prompt_template_id='baseline' few_shot_examples=[]
# id='DP2_scope12' question='Are the scope 1 and 2 emission reported?' include=[] exclude=[] prompt_template_id='baseline' few_shot_examples=[]
# id='DP2_scope12' question='Are the scope 1 and 2 emission reported?' include=[] exclude=[] prompt_template_id='baseline' few_shot_examples=[]
# id='DP2_scope12' question='Are the scope 1 and 2 emission reported?' include=[] exclude=[] prompt_template_id='baseline' few_shot_examples=[]
# id='DP2_scope12' question='Are the scope 1 and 2 emission reported?' include=[] exclude=[] prompt_template_id='baseline' few_shot_examples=[]
# id='DP2_scope12' question='Are the scope 1 and 2 emission reported?' include=[] exclude=[] prompt_template_id='baseline' few_shot_examples=[]
# id='DP2_scope12' question='Are the scope 1 and 2 emission reported?' include=[] exclude=[] prompt_template_id='baseline' few_shot_examples=[]
# id='DP2_scope12' question='Are the scope 1 and 2 emission reported?' include=[] exclude=[] prompt_template_id='baseline' few_shot_examples=[]
# id='DP2_scope12' question='Are the scope 1 and 2 emission reported?' include=[] exclude=[] prompt_template_id='baseline' few_shot_examples=[]
# id='DP2_scope12' question='Are the scope 1 and 2 emission reported?' include=[] exclude=[] prompt_template_id='baseline' few_shot_examples=[]
# id='DP2_scope12' question='Are the scope 1 and 2 emission reported?' include=[] exclude=[] prompt_template_id='baseline' few_shot_examples=[]
# id='DP2_scope12' question='Are the scope 1 and 2 emission reported?' include=[] exclude=[] prompt_template_id='baseline' few_shot_examples=[]
# id='DP2_scope12' question='Are the scope 1 and 2 emission reported?' include=[] exclude=[] prompt_template_id='baseline' few_shot_examples=[]
# id='DP2_scope12' question='Are the scope 1 and 2 emission reported?' include=[] exclude=[] prompt_template_id='baseline' few_shot_examples=[]
# id='DP2_scope12' question='Are the scope 1 and 2 emission reported?' include=[] exclude=[] prompt_template_id='baseline' few_shot_examples=[]
# id='DP2_scope12' question='Are the scope 1 and 2 emission reported?' include=[] exclude=[] prompt_template_id='baseline' few_shot_examples=[]
# id='DP2_scope12' question='Are the scope 1 and 2 emission reported?' include=[] exclude=[] prompt_template_id='baseline' few_shot_examples=[]
# id='DP2_scope12' question='Are the scope 1 and 2 emission reported?' include=[] exclude=[] prompt_template_id='baseline' few_shot_examples=[]
# id='DP2_scope12' question='Are the scope 1 and 2 emission reported?' include=[] exclude=[] prompt_template_id='baseline' few_shot_examples=[]
# 100%|██████████| 50/50 [03:48<00:00,  4.57s/it]
#   7%|▋         | 1/15 [03:48<53:20, 228.59s/it]
# id='DP2_scope12' question='Are the scope 1 and 2 emission reported?' include=[] exclude=[] prompt_template_id='baseline' few_shot_examples=[]
# id='DP2_scope12' question='Are the scope 1 and 2 emission reported?' include=[] exclude=[] prompt_template_id='baseline' few_shot_examples=[]
# id='DP2_scope12' question='Are the scope 1 and 2 emission reported?' include=[] exclude=[] prompt_template_id='baseline' few_shot_examples=[]
# id='DP2_scope12' question='Are the scope 1 and 2 emission reported?' include=[] exclude=[] prompt_template_id='baseline' few_shot_examples=[]
# id='DP2_scope12' question='Are the scope 1 and 2 emission reported?' include=[] exclude=[] prompt_template_id='baseline' few_shot_examples=[]
# id='DP2_scope12' question='Are the scope 1 and 2 emission reported?' include=[] exclude=[] prompt_template_id='baseline' few_shot_examples=[]
# id='DP2_scope12' question='Are the scope 1 and 2 emission reported?' include=[] exclude=[] prompt_template_id='baseline' few_shot_examples=[]
# id='DP2_scope12' question='Are the scope 1 and 2 emission reported?' include=[] exclude=[] prompt_template_id='baseline' few_shot_examples=[]
# id='DP2_scope12' question='Are the scope 1 and 2 emission reported?' include=[] exclude=[] prompt_template_id='baseline' few_shot_examples=[]
# id='DP2_scope12' question='Are the scope 1 and 2 emission reported?' include=[] exclude=[] prompt_template_id='baseline' few_shot_examples=[]
# id='DP2_scope12' question='Are the scope 1 and 2 emission reported?' include=[] exclude=[] prompt_template_id='baseline' few_shot_examples=[]
# id='DP2_scope12' question='Are the scope 1 and 2 emission reported?' include=[] exclude=[] prompt_template_id='baseline' few_shot_examples=[]
# id='DP2_scope12' question='Are the scope 1 and 2 emission reported?' include=[] exclude=[] prompt_template_id='baseline' few_shot_examples=[]
# id='DP2_scope12' question='Are the scope 1 and 2 emission reported?' include=[] exclude=[] prompt_template_id='baseline' few_shot_examples=[]
# id='DP2_scope12' question='Are the scope 1 and 2 emission reported?' include=[] exclude=[] prompt_template_id='baseline' few_shot_examples=[]
# id='DP2_scope12' question='Are the scope 1 and 2 emission reported?' include=[] exclude=[] prompt_template_id='baseline' few_shot_examples=[]
# id='DP2_scope12' question='Are the scope 1 and 2 emission reported?' include=[] exclude=[] prompt_template_id='baseline' few_shot_examples=[]
# id='DP2_scope12' question='Are the scope 1 and 2 emission reported?' include=[] exclude=[] prompt_template_id='baseline' few_shot_examples=[]
# id='DP2_scope12' question='Are the scope 1 and 2 emission reported?' include=[] exclude=[] prompt_template_id='baseline' few_shot_examples=[]
# id='DP2_scope12' question='Are the scope 1 and 2 emission reported?' include=[] exclude=[] prompt_template_id='baseline' few_shot_examples=[]
# id='DP2_scope12' question='Are the scope 1 and 2 emission reported?' include=[] exclude=[] prompt_template_id='baseline' few_shot_examples=[]
# id='DP2_scope12' question='Are the scope 1 and 2 emission reported?' include=[] exclude=[] prompt_template_id='baseline' few_shot_examples=[]
# id='DP2_scope12' question='Are the scope 1 and 2 emission reported?' include=[] exclude=[] prompt_template_id='baseline' few_shot_examples=[]
# id='DP2_scope12' question='Are the scope 1 and 2 emission reported?' include=[] exclude=[] prompt_template_id='baseline' few_shot_examples=[]
# id='DP2_scope12' question='Are the scope 1 and 2 emission reported?' include=[] exclude=[] prompt_template_id='baseline' few_shot_examples=[]
# id='DP2_scope12' question='Are the scope 1 and 2 emission reported?' include=[] exclude=[] prompt_template_id='baseline' few_shot_examples=[]
# id='DP2_scope12' question='Are the scope 1 and 2 emission reported?' include=[] exclude=[] prompt_template_id='baseline' few_shot_examples=[]
# id='DP2_scope12' question='Are the scope 1 and 2 emission reported?' include=[] exclude=[] prompt_template_id='baseline' few_shot_examples=[]
# id='DP2_scope12' question='Are the scope 1 and 2 emission reported?' include=[] exclude=[] prompt_template_id='baseline' few_shot_examples=[]
# id='DP2_scope12' question='Are the scope 1 and 2 emission reported?' include=[] exclude=[] prompt_template_id='baseline' few_shot_examples=[]
# id='DP2_scope12' question='Are the scope 1 and 2 emission reported?' include=[] exclude=[] prompt_template_id='baseline' few_shot_examples=[]
# id='DP2_scope12' question='Are the scope 1 and 2 emission reported?' include=[] exclude=[] prompt_template_id='baseline' few_shot_examples=[]
# id='DP2_scope12' question='Are the scope 1 and 2 emission reported?' include=[] exclude=[] prompt_template_id='baseline' few_shot_examples=[]
# id='DP2_scope12' question='Are the scope 1 and 2 emission reported?' include=[] exclude=[] prompt_template_id='baseline' few_shot_examples=[]
# id='DP2_scope12' question='Are the scope 1 and 2 emission reported?' include=[] exclude=[] prompt_template_id='baseline' few_shot_examples=[]
# id='DP2_scope12' question='Are the scope 1 and 2 emission reported?' include=[] exclude=[] prompt_template_id='baseline' few_shot_examples=[]
# id='DP2_scope12' question='Are the scope 1 and 2 emission reported?' include=[] exclude=[] prompt_template_id='baseline' few_shot_examples=[]
# id='DP2_scope12' question='Are the scope 1 and 2 emission reported?' include=[] exclude=[] prompt_template_id='baseline' few_shot_examples=[]
# id='DP2_scope12' question='Are the scope 1 and 2 emission reported?' include=[] exclude=[] prompt_template_id='baseline' few_shot_examples=[]
# id='DP2_scope12' question='Are the scope 1 and 2 emission reported?' include=[] exclude=[] prompt_template_id='baseline' few_shot_examples=[]
# id='DP2_scope12' question='Are the scope 1 and 2 emission reported?' include=[] exclude=[] prompt_template_id='baseline' few_shot_examples=[]
# id='DP2_scope12' question='Are the scope 1 and 2 emission reported?' include=[] exclude=[] prompt_template_id='baseline' few_shot_examples=[]
# id='DP2_scope12' question='Are the scope 1 and 2 emission reported?' include=[] exclude=[] prompt_template_id='baseline' few_shot_examples=[]
# id='DP2_scope12' question='Are the scope 1 and 2 emission reported?' include=[] exclude=[] prompt_template_id='baseline' few_shot_examples=[]
# id='DP2_scope12' question='Are the scope 1 and 2 emission reported?' include=[] exclude=[] prompt_template_id='baseline' few_shot_examples=[]
# id='DP2_scope12' question='Are the scope 1 and 2 emission reported?' include=[] exclude=[] prompt_template_id='baseline' few_shot_examples=[]
# id='DP2_scope12' question='Are the scope 1 and 2 emission reported?' include=[] exclude=[] prompt_template_id='baseline' few_shot_examples=[]
# id='DP2_scope12' question='Are the scope 1 and 2 emission reported?' include=[] exclude=[] prompt_template_id='baseline' few_shot_examples=[]
# id='DP2_scope12' question='Are the scope 1 and 2 emission reported?' include=[] exclude=[] prompt_template_id='baseline' few_shot_examples=[]
# id='DP2_scope12' question='Are the scope 1 and 2 emission reported?' include=[] exclude=[] prompt_template_id='baseline' few_shot_examples=[]
# id='DP2_scope12' question='Are the scope 1 and 2 emission reported?' include=[] exclude=[] prompt_template_id='baseline' few_shot_examples=[]
# id='DP2_scope12' question='Are the scope 1 and 2 emission reported?' include=[] exclude=[] prompt_template_id='baseline' few_shot_examples=[]
# id='DP2_scope12' question='Are the scope 1 and 2 emission reported?' include=[] exclude=[] prompt_template_id='baseline' few_shot_examples=[]
# id='DP2_scope12' question='Are the scope 1 and 2 emission reported?' include=[] exclude=[] prompt_template_id='baseline' few_shot_examples=[]
# id='DP2_scope12' question='Are the scope 1 and 2 emission reported?' include=[] exclude=[] prompt_template_id='baseline' few_shot_examples=[]
# id='DP2_scope12' question='Are the scope 1 and 2 emission reported?' include=[] exclude=[] prompt_template_id='baseline' few_shot_examples=[]
# id='DP2_scope12' question='Are the scope 1 and 2 emission reported?' include=[] exclude=[] prompt_template_id='baseline' few_shot_examples=[]
# id='DP2_scope12' question='Are the scope 1 and 2 emission reported?' include=[] exclude=[] prompt_template_id='baseline' few_shot_examples=[]
# id='DP2_scope12' question='Are the scope 1 and 2 emission reported?' include=[] exclude=[] prompt_template_id='baseline' few_shot_examples=[]
# id='DP2_scope12' question='Are the scope 1 and 2 emission reported?' include=[] exclude=[] prompt_template_id='baseline' few_shot_examples=[]
# id='DP2_scope12' question='Are the scope 1 and 2 emission reported?' include=[] exclude=[] prompt_template_id='baseline' few_shot_examples=[]
# id='DP2_scope12' question='Are the scope 1 and 2 emission reported?' include=[] exclude=[] prompt_template_id='baseline' few_shot_examples=[]
# id='DP2_scope12' question='Are the scope 1 and 2 emission reported?' include=[] exclude=[] prompt_template_id='baseline' few_shot_examples=[]
# id='DP2_scope12' question='Are the scope 1 and 2 emission reported?' include=[] exclude=[] prompt_template_id='baseline' few_shot_examples=[]
# id='DP2_scope12' question='Are the scope 1 and 2 emission reported?' include=[] exclude=[] prompt_template_id='baseline' few_shot_examples=[]
# id='DP2_scope12' question='Are the scope 1 and 2 emission reported?' include=[] exclude=[] prompt_template_id='baseline' few_shot_examples=[]
# id='DP2_scope12' question='Are the scope 1 and 2 emission reported?' include=[] exclude=[] prompt_template_id='baseline' few_shot_examples=[]
# id='DP2_scope12' question='Are the scope 1 and 2 emission reported?' include=[] exclude=[] prompt_template_id='baseline' few_shot_examples=[]
# id='DP2_scope12' question='Are the scope 1 and 2 emission reported?' include=[] exclude=[] prompt_template_id='baseline' few_shot_examples=[]
# id='DP2_scope12' question='Are the scope 1 and 2 emission reported?' include=[] exclude=[] prompt_template_id='baseline' few_shot_examples=[]
# id='DP2_scope12' question='Are the scope 1 and 2 emission reported?' include=[] exclude=[] prompt_template_id='baseline' few_shot_examples=[]
# id='DP2_scope12' question='Are the scope 1 and 2 emission reported?' include=[] exclude=[] prompt_template_id='baseline' few_shot_examples=[]
# id='DP2_scope12' question='Are the scope 1 and 2 emission reported?' include=[] exclude=[] prompt_template_id='baseline' few_shot_examples=[]
# id='DP2_scope12' question='Are the scope 1 and 2 emission reported?' include=[] exclude=[] prompt_template_id='baseline' few_shot_examples=[]
# id='DP2_scope12' question='Are the scope 1 and 2 emission reported?' include=[] exclude=[] prompt_template_id='baseline' few_shot_examples=[]
# id='DP2_scope12' question='Are the scope 1 and 2 emission reported?' include=[] exclude=[] prompt_template_id='baseline' few_shot_examples=[]
# id='DP2_scope12' question='Are the scope 1 and 2 emission reported?' include=[] exclude=[] prompt_template_id='baseline' few_shot_examples=[]
# id='DP2_scope12' question='Are the scope 1 and 2 emission reported?' include=[] exclude=[] prompt_template_id='baseline' few_shot_examples=[]
# id='DP2_scope12' question='Are the scope 1 and 2 emission reported?' include=[] exclude=[] prompt_template_id='baseline' few_shot_examples=[]
# id='DP2_scope12' question='Are the scope 1 and 2 emission reported?' include=[] exclude=[] prompt_template_id='baseline' few_shot_examples=[]
# id='DP2_scope12' question='Are the scope 1 and 2 emission reported?' include=[] exclude=[] prompt_template_id='baseline' few_shot_examples=[]
# id='DP2_scope12' question='Are the scope 1 and 2 emission reported?' include=[] exclude=[] prompt_template_id='baseline' few_shot_examples=[]
# id='DP2_scope12' question='Are the scope 1 and 2 emission reported?' include=[] exclude=[] prompt_template_id='baseline' few_shot_examples=[]
# id='DP2_scope12' question='Are the scope 1 and 2 emission reported?' include=[] exclude=[] prompt_template_id='baseline' few_shot_examples=[]
# id='DP2_scope12' question='Are the scope 1 and 2 emission reported?' include=[] exclude=[] prompt_template_id='baseline' few_shot_examples=[]
# id='DP2_scope12' question='Are the scope 1 and 2 emission reported?' include=[] exclude=[] prompt_template_id='baseline' few_shot_examples=[]
# id='DP2_scope12' question='Are the scope 1 and 2 emission reported?' include=[] exclude=[] prompt_template_id='baseline' few_shot_examples=[]
# id='DP2_scope12' question='Are the scope 1 and 2 emission reported?' include=[] exclude=[] prompt_template_id='baseline' few_shot_examples=[]
# id='DP2_scope12' question='Are the scope 1 and 2 emission reported?' include=[] exclude=[] prompt_template_id='baseline' few_shot_examples=[]
# id='DP2_scope12' question='Are the scope 1 and 2 emission reported?' include=[] exclude=[] prompt_template_id='baseline' few_shot_examples=[]
# id='DP2_scope12' question='Are the scope 1 and 2 emission reported?' include=[] exclude=[] prompt_template_id='baseline' few_shot_examples=[]
# id='DP2_scope12' question='Are the scope 1 and 2 emission reported?' include=[] exclude=[] prompt_template_id='baseline' few_shot_examples=[]
# id='DP2_scope12' question='Are the scope 1 and 2 emission reported?' include=[] exclude=[] prompt_template_id='baseline' few_shot_examples=[]
# id='DP2_scope12' question='Are the scope 1 and 2 emission reported?' include=[] exclude=[] prompt_template_id='baseline' few_shot_examples=[]
# id='DP2_scope12' question='Are the scope 1 and 2 emission reported?' include=[] exclude=[] prompt_template_id='baseline' few_shot_examples=[]
# id='DP2_scope12' question='Are the scope 1 and 2 emission reported?' include=[] exclude=[] prompt_template_id='baseline' few_shot_examples=[]
# id='DP2_scope12' question='Are the scope 1 and 2 emission reported?' include=[] exclude=[] prompt_template_id='baseline' few_shot_examples=[]
# id='DP2_scope12' question='Are the scope 1 and 2 emission reported?' include=[] exclude=[] prompt_template_id='baseline' few_shot_examples=[]
# id='DP2_scope12' question='Are the scope 1 and 2 emission reported?' include=[] exclude=[] prompt_template_id='baseline' few_shot_examples=[]
# id='DP2_scope12' question='Are the scope 1 and 2 emission reported?' include=[] exclude=[] prompt_template_id='baseline' few_shot_examples=[]
# id='DP2_scope12' question='Are the scope 1 and 2 emission reported?' include=[] exclude=[] prompt_template_id='baseline' few_shot_examples=[]
# id='DP2_scope12' question='Are the scope 1 and 2 emission reported?' include=[] exclude=[] prompt_template_id='baseline' few_shot_examples=[]
# id='DP2_scope12' question='Are the scope 1 and 2 emission reported?' include=[] exclude=[] prompt_template_id='baseline' few_shot_examples=[]
# id='DP2_scope12' question='Are the scope 1 and 2 emission reported?' include=[] exclude=[] prompt_template_id='baseline' few_shot_examples=[]
# id='DP2_scope12' question='Are the scope 1 and 2 emission reported?' include=[] exclude=[] prompt_template_id='baseline' few_shot_examples=[]
# id='DP2_scope12' question='Are the scope 1 and 2 emission reported?' include=[] exclude=[] prompt_template_id='baseline' few_shot_examples=[]
# id='DP2_scope12' question='Are the scope 1 and 2 emission reported?' include=[] exclude=[] prompt_template_id='baseline' few_shot_examples=[]
# id='DP2_scope12' question='Are the scope 1 and 2 emission reported?' include=[] exclude=[] prompt_template_id='baseline' few_shot_examples=[]
# id='DP2_scope12' question='Are the scope 1 and 2 emission reported?' include=[] exclude=[] prompt_template_id='baseline' few_shot_examples=[]
# id='DP2_scope12' question='Are the scope 1 and 2 emission reported?' include=[] exclude=[] prompt_template_id='baseline' few_shot_examples=[]
# id='DP2_scope12' question='Are the scope 1 and 2 emission reported?' include=[] exclude=[] prompt_template_id='baseline' few_shot_examples=[]
# id='DP2_scope12' question='Are the scope 1 and 2 emission reported?' include=[] exclude=[] prompt_template_id='baseline' few_shot_examples=[]
# id='DP2_scope12' question='Are the scope 1 and 2 emission reported?' include=[] exclude=[] prompt_template_id='baseline' few_shot_examples=[]
# id='DP2_scope12' question='Are the scope 1 and 2 emission reported?' include=[] exclude=[] prompt_template_id='baseline' few_shot_examples=[]
# id='DP2_scope12' question='Are the scope 1 and 2 emission reported?' include=[] exclude=[] prompt_template_id='baseline' few_shot_examples=[]
# id='DP2_scope12' question='Are the scope 1 and 2 emission reported?' include=[] exclude=[] prompt_template_id='baseline' few_shot_examples=[]
# id='DP2_scope12' question='Are the scope 1 and 2 emission reported?' include=[] exclude=[] prompt_template_id='baseline' few_shot_examples=[]
# id='DP2_scope12' question='Are the scope 1 and 2 emission reported?' include=[] exclude=[] prompt_template_id='baseline' few_shot_examples=[]
# id='DP2_scope12' question='Are the scope 1 and 2 emission reported?' include=[] exclude=[] prompt_template_id='baseline' few_shot_examples=[]
# id='DP2_scope12' question='Are the scope 1 and 2 emission reported?' include=[] exclude=[] prompt_template_id='baseline' few_shot_examples=[]
# id='DP2_scope12' question='Are the scope 1 and 2 emission reported?' include=[] exclude=[] prompt_template_id='baseline' few_shot_examples=[]
# id='DP2_scope12' question='Are the scope 1 and 2 emission reported?' include=[] exclude=[] prompt_template_id='baseline' few_shot_examples=[]
# id='DP2_scope12' question='Are the scope 1 and 2 emission reported?' include=[] exclude=[] prompt_template_id='baseline' few_shot_examples=[]
# id='DP2_scope12' question='Are the scope 1 and 2 emission reported?' include=[] exclude=[] prompt_template_id='baseline' few_shot_examples=[]
# id='DP2_scope12' question='Are the scope 1 and 2 emission reported?' include=[] exclude=[] prompt_template_id='baseline' few_shot_examples=[]
# id='DP2_scope12' question='Are the scope 1 and 2 emission reported?' include=[] exclude=[] prompt_template_id='baseline' few_shot_examples=[]
# id='DP2_scope12' question='Are the scope 1 and 2 emission reported?' include=[] exclude=[] prompt_template_id='baseline' few_shot_examples=[]
# id='DP2_scope12' question='Are the scope 1 and 2 emission reported?' include=[] exclude=[] prompt_template_id='baseline' few_shot_examples=[]
# id='DP2_scope12' question='Are the scope 1 and 2 emission reported?' include=[] exclude=[] prompt_template_id='baseline' few_shot_examples=[]
# id='DP2_scope12' question='Are the scope 1 and 2 emission reported?' include=[] exclude=[] prompt_template_id='baseline' few_shot_examples=[]
# id='DP2_scope12' question='Are the scope 1 and 2 emission reported?' include=[] exclude=[] prompt_template_id='baseline' few_shot_examples=[]
# id='DP2_scope12' question='Are the scope 1 and 2 emission reported?' include=[] exclude=[] prompt_template_id='baseline' few_shot_examples=[]
# id='DP2_scope12' question='Are the scope 1 and 2 emission reported?' include=[] exclude=[] prompt_template_id='baseline' few_shot_examples=[]
# id='DP2_scope12' question='Are the scope 1 and 2 emission reported?' include=[] exclude=[] prompt_template_id='baseline' few_shot_examples=[]
# id='DP2_scope12' question='Are the scope 1 and 2 emission reported?' include=[] exclude=[] prompt_template_id='baseline' few_shot_examples=[]
# id='DP2_scope12' question='Are the scope 1 and 2 emission reported?' include=[] exclude=[] prompt_template_id='baseline' few_shot_examples=[]
# id='DP2_scope12' question='Are the scope 1 and 2 emission reported?' include=[] exclude=[] prompt_template_id='baseline' few_shot_examples=[]
# id='DP2_scope12' question='Are the scope 1 and 2 emission reported?' include=[] exclude=[] prompt_template_id='baseline' few_shot_examples=[]
# id='DP2_scope12' question='Are the scope 1 and 2 emission reported?' include=[] exclude=[] prompt_template_id='baseline' few_shot_examples=[]
# id='DP2_scope12' question='Are the scope 1 and 2 emission reported?' include=[] exclude=[] prompt_template_id='baseline' few_shot_examples=[]
# id='DP2_scope12' question='Are the scope 1 and 2 emission reported?' include=[] exclude=[] prompt_template_id='baseline' few_shot_examples=[]
# id='DP2_scope12' question='Are the scope 1 and 2 emission reported?' include=[] exclude=[] prompt_template_id='baseline' few_shot_examples=[]
# id='DP2_scope12' question='Are the scope 1 and 2 emission reported?' include=[] exclude=[] prompt_template_id='baseline' few_shot_examples=[]
# id='DP2_scope12' question='Are the scope 1 and 2 emission reported?' include=[] exclude=[] prompt_template_id='baseline' few_shot_examples=[]
# id='DP2_scope12' question='Are the scope 1 and 2 emission reported?' include=[] exclude=[] prompt_template_id='baseline' few_shot_examples=[]
# id='DP2_scope12' question='Are the scope 1 and 2 emission reported?' include=[] exclude=[] prompt_template_id='baseline' few_shot_examples=[]
# id='DP2_scope12' question='Are the scope 1 and 2 emission reported?' include=[] exclude=[] prompt_template_id='baseline' few_shot_examples=[]
# id='DP2_scope12' question='Are the scope 1 and 2 emission reported?' include=[] exclude=[] prompt_template_id='baseline' few_shot_examples=[]
# id='DP2_scope12' question='Are the scope 1 and 2 emission reported?' include=[] exclude=[] prompt_template_id='baseline' few_shot_examples=[]
# id='DP2_scope12' question='Are the scope 1 and 2 emission reported?' include=[] exclude=[] prompt_template_id='baseline' few_shot_examples=[]
# id='DP2_scope12' question='Are the scope 1 and 2 emission reported?' include=[] exclude=[] prompt_template_id='baseline' few_shot_examples=[]
# id='DP2_scope12' question='Are the scope 1 and 2 emission reported?' include=[] exclude=[] prompt_template_id='baseline' few_shot_examples=[]
# id='DP2_scope12' question='Are the scope 1 and 2 emission reported?' include=[] exclude=[] prompt_template_id='baseline' few_shot_examples=[]
# id='DP2_scope12' question='Are the scope 1 and 2 emission reported?' include=[] exclude=[] prompt_template_id='baseline' few_shot_examples=[]
# id='DP2_scope12' question='Are the scope 1 and 2 emission reported?' include=[] exclude=[] prompt_template_id='baseline' few_shot_examples=[]
# id='DP2_scope12' question='Are the scope 1 and 2 emission reported?' include=[] exclude=[] prompt_template_id='baseline' few_shot_examples=[]
# id='DP2_scope12' question='Are the scope 1 and 2 emission reported?' include=[] exclude=[] prompt_template_id='baseline' few_shot_examples=[]
# id='DP2_scope12' question='Are the scope 1 and 2 emission reported?' include=[] exclude=[] prompt_template_id='baseline' few_shot_examples=[]
# id='DP2_scope12' question='Are the scope 1 and 2 emission reported?' include=[] exclude=[] prompt_template_id='baseline' few_shot_examples=[]
# id='DP2_scope12' question='Are the scope 1 and 2 emission reported?' include=[] exclude=[] prompt_template_id='baseline' few_shot_examples=[]
# id='DP2_scope12' question='Are the scope 1 and 2 emission reported?' include=[] exclude=[] prompt_template_id='baseline' few_shot_examples=[]
# id='DP2_scope12' question='Are the scope 1 and 2 emission reported?' include=[] exclude=[] prompt_template_id='baseline' few_shot_examples=[]
# id='DP2_scope12' question='Are the scope 1 and 2 emission reported?' include=[] exclude=[] prompt_template_id='baseline' few_shot_examples=[]
# id='DP2_scope12' question='Are the scope 1 and 2 emission reported?' include=[] exclude=[] prompt_template_id='baseline' few_shot_examples=[]
# id='DP2_scope12' question='Are the scope 1 and 2 emission reported?' include=[] exclude=[] prompt_template_id='baseline' few_shot_examples=[]
# id='DP2_scope12' question='Are the scope 1 and 2 emission reported?' include=[] exclude=[] prompt_template_id='baseline' few_shot_examples=[]
# id='DP2_scope12' question='Are the scope 1 and 2 emission reported?' include=[] exclude=[] prompt_template_id='baseline' few_shot_examples=[]
# id='DP2_scope12' question='Are the scope 1 and 2 emission reported?' include=[] exclude=[] prompt_template_id='baseline' few_shot_examples=[]
# id='DP2_scope12' question='Are the scope 1 and 2 emission reported?' include=[] exclude=[] prompt_template_id='baseline' few_shot_examples=[]
# id='DP2_scope12' question='Are the scope 1 and 2 emission reported?' include=[] exclude=[] prompt_template_id='baseline' few_shot_examples=[]
# id='DP2_scope12' question='Are the scope 1 and 2 emission reported?' include=[] exclude=[] prompt_template_id='baseline' few_shot_examples=[]
# id='DP2_scope12' question='Are the scope 1 and 2 emission reported?' include=[] exclude=[] prompt_template_id='baseline' few_shot_examples=[]
# id='DP2_scope12' question='Are the scope 1 and 2 emission reported?' include=[] exclude=[] prompt_template_id='baseline' few_shot_examples=[]
# id='DP2_scope12' question='Are the scope 1 and 2 emission reported?' include=[] exclude=[] prompt_template_id='baseline' few_shot_examples=[]
# id='DP2_scope12' question='Are the scope 1 and 2 emission reported?' include=[] exclude=[] prompt_template_id='baseline' few_shot_examples=[]
# id='DP2_scope12' question='Are the scope 1 and 2 emission reported?' include=[] exclude=[] prompt_template_id='baseline' few_shot_examples=[]
# id='DP2_scope12' question='Are the scope 1 and 2 emission reported?' include=[] exclude=[] prompt_template_id='baseline' few_shot_examples=[]
# id='DP2_scope12' question='Are the scope 1 and 2 emission reported?' include=[] exclude=[] prompt_template_id='baseline' few_shot_examples=[]
# id='DP2_scope12' question='Are the scope 1 and 2 emission reported?' include=[] exclude=[] prompt_template_id='baseline' few_shot_examples=[]
# id='DP2_scope12' question='Are the scope 1 and 2 emission reported?' include=[] exclude=[] prompt_template_id='baseline' few_shot_examples=[]
# id='DP2_scope12' question='Are the scope 1 and 2 emission reported?' include=[] exclude=[] prompt_template_id='baseline' few_shot_examples=[]
# id='DP2_scope12' question='Are the scope 1 and 2 emission reported?' include=[] exclude=[] prompt_template_id='baseline' few_shot_examples=[]
# id='DP2_scope12' question='Are the scope 1 and 2 emission reported?' include=[] exclude=[] prompt_template_id='baseline' few_shot_examples=[]
# id='DP2_scope12' question='Are the scope 1 and 2 emission reported?' include=[] exclude=[] prompt_template_id='baseline' few_shot_examples=[]
# id='DP2_scope12' question='Are the scope 1 and 2 emission reported?' include=[] exclude=[] prompt_template_id='baseline' few_shot_examples=[]
# id='DP2_scope12' question='Are the scope 1 and 2 emission reported?' include=[] exclude=[] prompt_template_id='baseline' few_shot_examples=[]
# id='DP2_scope12' question='Are the scope 1 and 2 emission reported?' include=[] exclude=[] prompt_template_id='baseline' few_shot_examples=[]
# id='DP2_scope12' question='Are the scope 1 and 2 emission reported?' include=[] exclude=[] prompt_template_id='baseline' few_shot_examples=[]
# id='DP2_scope12' question='Are the scope 1 and 2 emission reported?' include=[] exclude=[] prompt_template_id='baseline' few_shot_examples=[]
# id='DP2_scope12' question='Are the scope 1 and 2 emission reported?' include=[] exclude=[] prompt_template_id='baseline' few_shot_examples=[]
# id='DP2_scope12' question='Are the scope 1 and 2 emission reported?' include=[] exclude=[] prompt_template_id='baseline' few_shot_examples=[]
# id='DP2_scope12' question='Are the scope 1 and 2 emission reported?' include=[] exclude=[] prompt_template_id='baseline' few_shot_examples=[]
# id='DP2_scope12' question='Are the scope 1 and 2 emission reported?' include=[] exclude=[] prompt_template_id='baseline' few_shot_examples=[]
# id='DP2_scope12' question='Are the scope 1 and 2 emission reported?' include=[] exclude=[] prompt_template_id='baseline' few_shot_examples=[]
# id='DP2_scope12' question='Are the scope 1 and 2 emission reported?' include=[] exclude=[] prompt_template_id='baseline' few_shot_examples=[]
# id='DP2_scope12' question='Are the scope 1 and 2 emission reported?' include=[] exclude=[] prompt_template_id='baseline' few_shot_examples=[]
# id='DP2_scope12' question='Are the scope 1 and 2 emission reported?' include=[] exclude=[] prompt_template_id='baseline' few_shot_examples=[]
# id='DP2_scope12' question='Are the scope 1 and 2 emission reported?' include=[] exclude=[] prompt_template_id='baseline' few_shot_examples=[]
# id='DP2_scope12' question='Are the scope 1 and 2 emission reported?' include=[] exclude=[] prompt_template_id='baseline' few_shot_examples=[]
# id='DP2_scope12' question='Are the scope 1 and 2 emission reported?' include=[] exclude=[] prompt_template_id='baseline' few_shot_examples=[]
# id='DP2_scope12' question='Are the scope 1 and 2 emission reported?' include=[] exclude=[] prompt_template_id='baseline' few_shot_examples=[]
# id='DP2_scope12' question='Are the scope 1 and 2 emission reported?' include=[] exclude=[] prompt_template_id='baseline' few_shot_examples=[]
# id='DP2_scope12' question='Are the scope 1 and 2 emission reported?' include=[] exclude=[] prompt_template_id='baseline' few_shot_examples=[]
# id='DP2_scope12' question='Are the scope 1 and 2 emission reported?' include=[] exclude=[] prompt_template_id='baseline' few_shot_examples=[]
# id='DP2_scope12' question='Are the scope 1 and 2 emission reported?' include=[] exclude=[] prompt_template_id='baseline' few_shot_examples=[]
# id='DP2_scope12' question='Are the scope 1 and 2 emission reported?' include=[] exclude=[] prompt_template_id='baseline' few_shot_examples=[]
# id='DP2_scope12' question='Are the scope 1 and 2 emission reported?' include=[] exclude=[] prompt_template_id='baseline' few_shot_examples=[]
# id='DP2_scope12' question='Are the scope 1 and 2 emission reported?' include=[] exclude=[] prompt_template_id='baseline' few_shot_examples=[]
# id='DP2_scope12' question='Are the scope 1 and 2 emission reported?' include=[] exclude=[] prompt_template_id='baseline' few_shot_examples=[]
# id='DP2_scope12' question='Are the scope 1 and 2 emission reported?' include=[] exclude=[] prompt_template_id='baseline' few_shot_examples=[]
# id='DP2_scope12' question='Are the scope 1 and 2 emission reported?' include=[] exclude=[] prompt_template_id='baseline' few_shot_examples=[]
# id='DP2_scope12' question='Are the scope 1 and 2 emission reported?' include=[] exclude=[] prompt_template_id='baseline' few_shot_examples=[]
# id='DP2_scope12' question='Are the scope 1 and 2 emission reported?' include=[] exclude=[] prompt_template_id='baseline' few_shot_examples=[]
# id='DP2_scope12' question='Are the scope 1 and 2 emission reported?' include=[] exclude=[] prompt_template_id='baseline' few_shot_examples=[]
# id='DP2_scope12' question='Are the scope 1 and 2 emission reported?' include=[] exclude=[] prompt_template_id='baseline' few_shot_examples=[]
# id='DP2_scope12' question='Are the scope 1 and 2 emission reported?' include=[] exclude=[] prompt_template_id='baseline' few_shot_examples=[]
# id='DP2_scope12' question='Are the scope 1 and 2 emission reported?' include=[] exclude=[] prompt_template_id='baseline' few_shot_examples=[]
# id='DP2_scope12' question='Are the scope 1 and 2 emission reported?' include=[] exclude=[] prompt_template_id='baseline' few_shot_examples=[]
# id='DP2_scope12' question='Are the scope 1 and 2 emission reported?' include=[] exclude=[] prompt_template_id='baseline' few_shot_examples=[]
# id='DP2_scope12' question='Are the scope 1 and 2 emission reported?' include=[] exclude=[] prompt_template_id='baseline' few_shot_examples=[]
# id='DP2_scope12' question='Are the scope 1 and 2 emission reported?' include=[] exclude=[] prompt_template_id='baseline' few_shot_examples=[]
# id='DP2_scope12' question='Are the scope 1 and 2 emission reported?' include=[] exclude=[] prompt_template_id='baseline' few_shot_examples=[]
# id='DP2_scope12' question='Are the scope 1 and 2 emission reported?' include=[] exclude=[] prompt_template_id='baseline' few_shot_examples=[]
# id='DP2_scope12' question='Are the scope 1 and 2 emission reported?' include=[] exclude=[] prompt_template_id='baseline' few_shot_examples=[]
# id='DP2_scope12' question='Are the scope 1 and 2 emission reported?' include=[] exclude=[] prompt_template_id='baseline' few_shot_examples=[]
# id='DP2_scope12' question='Are the scope 1 and 2 emission reported?' include=[] exclude=[] prompt_template_id='baseline' few_shot_examples=[]
# id='DP2_scope12' question='Are the scope 1 and 2 emission reported?' include=[] exclude=[] prompt_template_id='baseline' few_shot_examples=[]
# id='DP2_scope12' question='Are the scope 1 and 2 emission reported?' include=[] exclude=[] prompt_template_id='baseline' few_shot_examples=[]
# id='DP2_scope12' question='Are the scope 1 and 2 emission reported?' include=[] exclude=[] prompt_template_id='baseline' few_shot_examples=[]
# id='DP2_scope12' question='Are the scope 1 and 2 emission reported?' include=[] exclude=[] prompt_template_id='baseline' few_shot_examples=[]
# id='DP2_scope12' question='Are the scope 1 and 2 emission reported?' include=[] exclude=[] prompt_template_id='baseline' few_shot_examples=[]
# id='DP2_scope12' question='Are the scope 1 and 2 emission reported?' include=[] exclude=[] prompt_template_id='baseline' few_shot_examples=[]
# id='DP2_scope12' question='Are the scope 1 and 2 emission reported?' include=[] exclude=[] prompt_template_id='baseline' few_shot_examples=[]
# id='DP2_scope12' question='Are the scope 1 and 2 emission reported?' include=[] exclude=[] prompt_template_id='baseline' few_shot_examples=[]
# id='DP2_scope12' question='Are the scope 1 and 2 emission reported?' include=[] exclude=[] prompt_template_id='baseline' few_shot_examples=[]
# id='DP2_scope12' question='Are the scope 1 and 2 emission reported?' include=[] exclude=[] prompt_template_id='baseline' few_shot_examples=[]
# id='DP2_scope12' question='Are the scope 1 and 2 emission reported?' include=[] exclude=[] prompt_template_id='baseline' few_shot_examples=[]
# id='DP2_scope12' question='Are the scope 1 and 2 emission reported?' include=[] exclude=[] prompt_template_id='baseline' few_shot_examples=[]
# id='DP2_scope12' question='Are the scope 1 and 2 emission reported?' include=[] exclude=[] prompt_template_id='baseline' few_shot_examples=[]
# id='DP2_scope12' question='Are the scope 1 and 2 emission reported?' include=[] exclude=[] prompt_template_id='baseline' few_shot_examples=[]
# id='DP2_scope12' question='Are the scope 1 and 2 emission reported?' include=[] exclude=[] prompt_template_id='baseline' few_shot_examples=[]
# id='DP2_scope12' question='Are the scope 1 and 2 emission reported?' include=[] exclude=[] prompt_template_id='baseline' few_shot_examples=[]
# id='DP2_scope12' question='Are the scope 1 and 2 emission reported?' include=[] exclude=[] prompt_template_id='baseline' few_shot_examples=[]
# id='DP2_scope12' question='Are the scope 1 and 2 emission reported?' include=[] exclude=[] prompt_template_id='baseline' few_shot_examples=[]
# id='DP2_scope12' question='Are the scope 1 and 2 emission reported?' include=[] exclude=[] prompt_template_id='baseline' few_shot_examples=[]
# id='DP2_scope12' question='Are the scope 1 and 2 emission reported?' include=[] exclude=[] prompt_template_id='baseline' few_shot_examples=[]
# id='DP2_scope12' question='Are the scope 1 and 2 emission reported?' include=[] exclude=[] prompt_template_id='baseline' few_shot_examples=[]
# id='DP2_scope12' question='Are the scope 1 and 2 emission reported?' include=[] exclude=[] prompt_template_id='baseline' few_shot_examples=[]
# id='DP2_scope12' question='Are the scope 1 and 2 emission reported?' include=[] exclude=[] prompt_template_id='baseline' few_shot_examples=[]
# id='DP2_scope12' question='Are the scope 1 and 2 emission reported?' include=[] exclude=[] prompt_template_id='baseline' few_shot_examples=[]
# id='DP2_scope12' question='Are the scope 1 and 2 emission reported?' include=[] exclude=[] prompt_template_id='baseline' few_shot_examples=[]
# id='DP2_scope12' question='Are the scope 1 and 2 emission reported?' include=[] exclude=[] prompt_template_id='baseline' few_shot_examples=[]
# id='DP2_scope12' question='Are the scope 1 and 2 emission reported?' include=[] exclude=[] prompt_template_id='baseline' few_shot_examples=[]
# id='DP2_scope12' question='Are the scope 1 and 2 emission reported?' include=[] exclude=[] prompt_template_id='baseline' few_shot_examples=[]
# id='DP2_scope12' question='Are the scope 1 and 2 emission reported?' include=[] exclude=[] prompt_template_id='baseline' few_shot_examples=[]
# id='DP2_scope12' question='Are the scope 1 and 2 emission reported?' include=[] exclude=[] prompt_template_id='baseline' few_shot_examples=[]
# id='DP2_scope12' question='Are the scope 1 and 2 emission reported?' include=[] exclude=[] prompt_template_id='baseline' few_shot_examples=[]
# id='DP2_scope12' question='Are the scope 1 and 2 emission reported?' include=[] exclude=[] prompt_template_id='baseline' few_shot_examples=[]
# id='DP2_scope12' question='Are the scope 1 and 2 emission reported?' include=[] exclude=[] prompt_template_id='baseline' few_shot_examples=[]
# id='DP2_scope12' question='Are the scope 1 and 2 emission reported?' include=[] exclude=[] prompt_template_id='baseline' few_shot_examples=[]
# id='DP2_scope12' question='Are the scope 1 and 2 emission reported?' include=[] exclude=[] prompt_template_id='baseline' few_shot_examples=[]
# id='DP2_scope12' question='Are the scope 1 and 2 emission reported?' include=[] exclude=[] prompt_template_id='baseline' few_shot_examples=[]
# id='DP2_scope12' question='Are the scope 1 and 2 emission reported?' include=[] exclude=[] prompt_template_id='baseline' few_shot_examples=[]
# id='DP2_scope12' question='Are the scope 1 and 2 emission reported?' include=[] exclude=[] prompt_template_id='baseline' few_shot_examples=[]
# id='DP2_scope12' question='Are the scope 1 and 2 emission reported?' include=[] exclude=[] prompt_template_id='baseline' few_shot_examples=[]
# id='DP2_scope12' question='Are the scope 1 and 2 emission reported?' include=[] exclude=[] prompt_template_id='baseline' few_shot_examples=[]
# id='DP2_scope12' question='Are the scope 1 and 2 emission reported?' include=[] exclude=[] prompt_template_id='baseline' few_shot_examples=[]
# id='DP2_scope12' question='Are the scope 1 and 2 emission reported?' include=[] exclude=[] prompt_template_id='baseline' few_shot_examples=[]
# id='DP2_scope12' question='Are the scope 1 and 2 emission reported?' include=[] exclude=[] prompt_template_id='baseline' few_shot_examples=[]
# id='DP2_scope12' question='Are the scope 1 and 2 emission reported?' include=[] exclude=[] prompt_template_id='baseline' few_shot_examples=[]
# id='DP2_scope12' question='Are the scope 1 and 2 emission reported?' include=[] exclude=[] prompt_template_id='baseline' few_shot_examples=[]
# id='DP2_scope12' question='Are the scope 1 and 2 emission reported?' include=[] exclude=[] prompt_template_id='baseline' few_shot_examples=[]
# id='DP2_scope12' question='Are the scope 1 and 2 emission reported?' include=[] exclude=[] prompt_template_id='baseline' few_shot_examples=[]
# id='DP2_scope12' question='Are the scope 1 and 2 emission reported?' include=[] exclude=[] prompt_template_id='baseline' few_shot_examples=[]
# id='DP2_scope12' question='Are the scope 1 and 2 emission reported?' include=[] exclude=[] prompt_template_id='baseline' few_shot_examples=[]
# id='DP2_scope12' question='Are the scope 1 and 2 emission reported?' include=[] exclude=[] prompt_template_id='baseline' few_shot_examples=[]
# id='DP2_scope12' question='Are the scope 1 and 2 emission reported?' include=[] exclude=[] prompt_template_id='baseline' few_shot_examples=[]
# id='DP2_scope12' question='Are the scope 1 and 2 emission reported?' include=[] exclude=[] prompt_template_id='baseline' few_shot_examples=[]
# id='DP2_scope12' question='Are the scope 1 and 2 emission reported?' include=[] exclude=[] prompt_template_id='baseline' few_shot_examples=[]
# id='DP2_scope12' question='Are the scope 1 and 2 emission reported?' include=[] exclude=[] prompt_template_id='baseline' few_shot_examples=[]
# id='DP2_scope12' question='Are the scope 1 and 2 emission reported?' include=[] exclude=[] prompt_template_id='baseline' few_shot_examples=[]
# id='DP2_scope12' question='Are the scope 1 and 2 emission reported?' include=[] exclude=[] prompt_template_id='baseline' few_shot_examples=[]
# id='DP2_scope12' question='Are the scope 1 and 2 emission reported?' include=[] exclude=[] prompt_template_id='baseline' few_shot_examples=[]
# id='DP2_scope12' question='Are the scope 1 and 2 emission reported?' include=[] exclude=[] prompt_template_id='baseline' few_shot_examples=[]
# id='DP2_scope12' question='Are the scope 1 and 2 emission reported?' include=[] exclude=[] prompt_template_id='baseline' few_shot_examples=[]
# id='DP2_scope12' question='Are the scope 1 and 2 emission reported?' include=[] exclude=[] prompt_template_id='baseline' few_shot_examples=[]
# id='DP2_scope12' question='Are the scope 1 and 2 emission reported?' include=[] exclude=[] prompt_template_id='baseline' few_shot_examples=[]
# ...
# id='DP2_scope12' question='Are the scope 1 and 2 emission reported?' include=[] exclude=[] prompt_template_id='baseline' few_shot_examples=[]
# id='DP2_scope12' question='Are the scope 1 and 2 emission reported?' include=[] exclude=[] prompt_template_id='baseline' few_shot_examples=[]
# id='DP2_scope12' question='Are the scope 1 and 2 emission reported?' include=[] exclude=[] prompt_template_id='baseline' few_shot_examples=[]
# id='DP2_scope12' question='Are the scope 1 and 2 emission reported?' include=[] exclude=[] prompt_template_id='baseline' few_shot_examples=[]
# id='DP2_scope12' question='Are the scope 1 and 2 emission reported?' include=[] exclude=[] prompt_template_id='baseline' few_shot_examples=[]
# id='DP2_scope12' question='Are the scope 1 and 2 emission reported?' include=[] exclude=[] prompt_template_id='baseline' few_shot_examples=[]
# id='DP2_scope12' question='Are the scope 1 and 2 emission reported?' include=[] exclude=[] prompt_template_id='baseline' few_shot_examples=[]
# id='DP2_scope12' question='Are the scope 1 and 2 emission reported?' include=[] exclude=[] prompt_template_id='baseline' few_shot_examples=[]
# id='DP2_scope12' question='Are the scope 1 and 2 emission reported?' include=[] exclude=[] prompt_template_id='baseline' few_shot_examples=[]
# id='DP2_scope12' question='Are the scope 1 and 2 emission reported?' include=[] exclude=[] prompt_template_id='baseline' few_shot_examples=[]
# id='DP2_scope12' question='Are the scope 1 and 2 emission reported?' include=[] exclude=[] prompt_template_id='baseline' few_shot_examples=[]
# id='DP2_scope12' question='Are the scope 1 and 2 emission reported?' include=[] exclude=[] prompt_template_id='baseline' few_shot_examples=[]
# id='DP2_scope12' question='Are the scope 1 and 2 emission reported?' include=[] exclude=[] prompt_template_id='baseline' few_shot_examples=[]
# id='DP2_scope12' question='Are the scope 1 and 2 emission reported?' include=[] exclude=[] prompt_template_id='baseline' few_shot_examples=[]
# id='DP2_scope12' question='Are the scope 1 and 2 emission reported?' include=[] exclude=[] prompt_template_id='baseline' few_shot_examples=[]
# id='DP2_scope12' question='Are the scope 1 and 2 emission reported?' include=[] exclude=[] prompt_template_id='baseline' few_shot_examples=[]
# id='DP2_scope12' question='Are the scope 1 and 2 emission reported?' include=[] exclude=[] prompt_template_id='baseline' few_shot_examples=[]
# id='DP2_scope12' question='Are the scope 1 and 2 emission reported?' include=[] exclude=[] prompt_template_id='baseline' few_shot_examples=[]
# id='DP2_scope12' question='Are the scope 1 and 2 emission reported?' include=[] exclude=[] prompt_template_id='baseline' few_shot_examples=[]
# id='DP2_scope12' question='Are the scope 1 and 2 emission reported?' include=[] exclude=[] prompt_template_id='baseline' few_shot_examples=[]
# id='DP2_scope12' question='Are the scope 1 and 2 emission reported?' include=[] exclude=[] prompt_template_id='baseline' few_shot_examples=[]
# id='DP2_scope12' question='Are the scope 1 and 2 emission reported?' include=[] exclude=[] prompt_template_id='baseline' few_shot_examples=[]
# id='DP2_scope12' question='Are the scope 1 and 2 emission reported?' include=[] exclude=[] prompt_template_id='baseline' few_shot_examples=[]
# id='DP2_scope12' question='Are the scope 1 and 2 emission reported?' include=[] exclude=[] prompt_template_id='baseline' few_shot_examples=[]
# id='DP2_scope12' question='Are the scope 1 and 2 emission reported?' include=[] exclude=[] prompt_template_id='baseline' few_shot_examples=[]
# id='DP2_scope12' question='Are the scope 1 and 2 emission reported?' include=[] exclude=[] prompt_template_id='baseline' few_shot_examples=[]
# id='DP2_scope12' question='Are the scope 1 and 2 emission reported?' include=[] exclude=[] prompt_template_id='baseline' few_shot_examples=[]
# id='DP2_scope12' question='Are the scope 1 and 2 emission reported?' include=[] exclude=[] prompt_template_id='baseline' few_shot_examples=[]
# id='DP2_scope12' question='Are the scope 1 and 2 emission reported?' include=[] exclude=[] prompt_template_id='baseline' few_shot_examples=[]
# id='DP2_scope12' question='Are the scope 1 and 2 emission reported?' include=[] exclude=[] prompt_template_id='baseline' few_shot_examples=[]
# id='DP2_scope12' question='Are the scope 1 and 2 emission reported?' include=[] exclude=[] prompt_template_id='baseline' few_shot_examples=[]
# id='DP2_scope12' question='Are the scope 1 and 2 emission reported?' include=[] exclude=[] prompt_template_id='baseline' few_shot_examples=[]
# id='DP2_scope12' question='Are the scope 1 and 2 emission reported?' include=[] exclude=[] prompt_template_id='baseline' few_shot_examples=[]
# id='DP2_scope12' question='Are the scope 1 and 2 emission reported?' include=[] exclude=[] prompt_template_id='baseline' few_shot_examples=[]
# id='DP2_scope12' question='Are the scope 1 and 2 emission reported?' include=[] exclude=[] prompt_template_id='baseline' few_shot_examples=[]
# id='DP2_scope12' question='Are the scope 1 and 2 emission reported?' include=[] exclude=[] prompt_template_id='baseline' few_shot_examples=[]
# id='DP2_scope12' question='Are the scope 1 and 2 emission reported?' include=[] exclude=[] prompt_template_id='baseline' few_shot_examples=[]
# id='DP2_scope12' question='Are the scope 1 and 2 emission reported?' include=[] exclude=[] prompt_template_id='baseline' few_shot_examples=[]
# id='DP2_scope12' question='Are the scope 1 and 2 emission reported?' include=[] exclude=[] prompt_template_id='baseline' few_shot_examples=[]
#  98%|█████████▊| 391/400 [46:22<01:04,  7.12s/it]
#   7%|▋         | 1/15 [50:11<11:42:41, 3011.55s/it]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[45], line 20
#      11 for page in tqdm(report["pages"]):
#      12     prompt = prompts.render_prompt(
#      13             question,
#      14             page["markdown"],
#    (...)
#      17             truncate_at=None,
#      18         )
# ---> 20     llm_response = llm.invoke(prompt.text)
#      22     match = re.search(r"\{.*\}", llm_response, re.DOTALL)
#      23     if match:
#
# File ~/miniconda3/envs/financial_index/lib/python3.10/site-packages/langchain_core/language_models/llms.py:392, in BaseLLM.invoke(self, input, config, stop, **kwargs)
#     381 @override
#     382 def invoke(
#     383     self,
#    (...)
#     388     **kwargs: Any,
#     389 ) -> str:
#     390     config = ensure_config(config)
#     391     return (
# --> 392         self.generate_prompt(
#     393             [self._convert_input(input)],
#     394             stop=stop,
#     395             callbacks=config.get("callbacks"),
#     396             tags=config.get("tags"),
#     397             metadata=config.get("metadata"),
#     398             run_name=config.get("run_name"),
#     399             run_id=config.pop("run_id", None),
#     400             **kwargs,
#     401         )
#     402         .generations[0][0]
#     403         .text
#     404     )
#
# File ~/miniconda3/envs/financial_index/lib/python3.10/site-packages/langchain_core/language_models/llms.py:791, in BaseLLM.generate_prompt(self, prompts, stop, callbacks, **kwargs)
#     782 @override
#     783 def generate_prompt(
#     784     self,
#    (...)
#     788     **kwargs: Any,
#     789 ) -> LLMResult:
#     790     prompt_strings = [p.to_string() for p in prompts]
# --> 791     return self.generate(prompt_strings, stop=stop, callbacks=callbacks, **kwargs)
#
# File ~/miniconda3/envs/financial_index/lib/python3.10/site-packages/langchain_core/language_models/llms.py:1002, in BaseLLM.generate(self, prompts, stop, callbacks, tags, metadata, run_name, run_id, **kwargs)
#     987 if (self.cache is None and get_llm_cache() is None) or self.cache is False:
#     988     run_managers = [
#     989         callback_manager.on_llm_start(
#     990             self._serialized,
#    (...)
#    1000         )
#    1001     ]
# -> 1002     return self._generate_helper(
#    1003         prompts,
#    1004         stop,
#    1005         run_managers,
#    1006         new_arg_supported=bool(new_arg_supported),
#    1007         **kwargs,
#    1008     )
#    1009 if len(missing_prompts) > 0:
#    1010     run_managers = [
#    1011         callback_managers[idx].on_llm_start(
#    1012             self._serialized,
#    (...)
#    1019         for idx in missing_prompt_idxs
#    1020     ]
#
# File ~/miniconda3/envs/financial_index/lib/python3.10/site-packages/langchain_core/language_models/llms.py:817, in BaseLLM._generate_helper(self, prompts, stop, run_managers, new_arg_supported, **kwargs)
#     806 def _generate_helper(
#     807     self,
#     808     prompts: list[str],
#    (...)
#     813     **kwargs: Any,
#     814 ) -> LLMResult:
#     815     try:
#     816         output = (
# --> 817             self._generate(
#     818                 prompts,
#     819                 stop=stop,
#     820                 # TODO: support multiple run managers
#     821                 run_manager=run_managers[0] if run_managers else None,
#     822                 **kwargs,
#     823             )
#     824             if new_arg_supported
#     825             else self._generate(prompts, stop=stop)
#     826         )
#     827     except BaseException as e:
#     828         for run_manager in run_managers:
#
# File ~/miniconda3/envs/financial_index/lib/python3.10/site-packages/langchain_ollama/llms.py:459, in OllamaLLM._generate(self, prompts, stop, run_manager, **kwargs)
#     457 generations = []
#     458 for prompt in prompts:
# --> 459     final_chunk = self._stream_with_aggregation(
#     460         prompt,
#     461         stop=stop,
#     462         run_manager=run_manager,
#     463         verbose=self.verbose,
#     464         **kwargs,
#     465     )
#     466     generations.append([final_chunk])
#     467 return LLMResult(generations=generations)
#
# File ~/miniconda3/envs/financial_index/lib/python3.10/site-packages/langchain_ollama/llms.py:418, in OllamaLLM._stream_with_aggregation(self, prompt, stop, run_manager, verbose, **kwargs)
#     416 final_chunk = None
#     417 thinking_content = ""
# --> 418 for stream_resp in self._create_generate_stream(prompt, stop, **kwargs):
#     419     if not isinstance(stream_resp, str):
#     420         if stream_resp.get("thinking"):
#
# File ~/miniconda3/envs/financial_index/lib/python3.10/site-packages/langchain_ollama/llms.py:362, in OllamaLLM._create_generate_stream(self, prompt, stop, **kwargs)
#     355 def _create_generate_stream(
#     356     self,
#     357     prompt: str,
#     358     stop: Optional[list[str]] = None,
#     359     **kwargs: Any,
#     360 ) -> Iterator[Union[Mapping[str, Any], str]]:
#     361     if self._client:
# --> 362         yield from self._client.generate(
#     363             **self._generate_params(prompt, stop=stop, **kwargs)
#     364         )
#
# File ~/miniconda3/envs/financial_index/lib/python3.10/site-packages/ollama/_client.py:181, in Client._request.<locals>.inner()
#     178   e.response.read()
#     179   raise ResponseError(e.response.text, e.response.status_code) from None
# --> 181 for line in r.iter_lines():
#     182   part = json.loads(line)
#     183   if err := part.get('error'):
#
# File ~/miniconda3/envs/financial_index/lib/python3.10/site-packages/httpx/_models.py:929, in Response.iter_lines(self)
#     927 decoder = LineDecoder()
#     928 with request_context(request=self._request):
# --> 929     for text in self.iter_text():
#     930         for line in decoder.decode(text):
#     931             yield line
#
# File ~/miniconda3/envs/financial_index/lib/python3.10/site-packages/httpx/_models.py:916, in Response.iter_text(self, chunk_size)
#     914 chunker = TextChunker(chunk_size=chunk_size)
#     915 with request_context(request=self._request):
# --> 916     for byte_content in self.iter_bytes():
#     917         text_content = decoder.decode(byte_content)
#     918         for chunk in chunker.decode(text_content):
#
# File ~/miniconda3/envs/financial_index/lib/python3.10/site-packages/httpx/_models.py:897, in Response.iter_bytes(self, chunk_size)
#     895 chunker = ByteChunker(chunk_size=chunk_size)
#     896 with request_context(request=self._request):
# --> 897     for raw_bytes in self.iter_raw():
#     898         decoded = decoder.decode(raw_bytes)
#     899         for chunk in chunker.decode(decoded):
#
# File ~/miniconda3/envs/financial_index/lib/python3.10/site-packages/httpx/_models.py:951, in Response.iter_raw(self, chunk_size)
#     948 chunker = ByteChunker(chunk_size=chunk_size)
#     950 with request_context(request=self._request):
# --> 951     for raw_stream_bytes in self.stream:
#     952         self._num_bytes_downloaded += len(raw_stream_bytes)
#     953         for chunk in chunker.decode(raw_stream_bytes):
#
# File ~/miniconda3/envs/financial_index/lib/python3.10/site-packages/httpx/_client.py:153, in BoundSyncStream.__iter__(self)
#     152 def __iter__(self) -> typing.Iterator[bytes]:
# --> 153     for chunk in self._stream:
#     154         yield chunk
#
# File ~/miniconda3/envs/financial_index/lib/python3.10/site-packages/httpx/_transports/default.py:127, in ResponseStream.__iter__(self)
#     125 def __iter__(self) -> typing.Iterator[bytes]:
#     126     with map_httpcore_exceptions():
# --> 127         for part in self._httpcore_stream:
#     128             yield part
#
# File ~/miniconda3/envs/financial_index/lib/python3.10/site-packages/httpcore/_sync/connection_pool.py:407, in PoolByteStream.__iter__(self)
#     405 except BaseException as exc:
#     406     self.close()
# --> 407     raise exc from None
#
# File ~/miniconda3/envs/financial_index/lib/python3.10/site-packages/httpcore/_sync/connection_pool.py:403, in PoolByteStream.__iter__(self)
#     401 def __iter__(self) -> typing.Iterator[bytes]:
#     402     try:
# --> 403         for part in self._stream:
#     404             yield part
#     405     except BaseException as exc:
#
# File ~/miniconda3/envs/financial_index/lib/python3.10/site-packages/httpcore/_sync/http11.py:342, in HTTP11ConnectionByteStream.__iter__(self)
#     340 with ShieldCancellation():
#     341     self.close()
# --> 342 raise exc
#
# File ~/miniconda3/envs/financial_index/lib/python3.10/site-packages/httpcore/_sync/http11.py:334, in HTTP11ConnectionByteStream.__iter__(self)
#     332 try:
#     333     with Trace("receive_response_body", logger, self._request, kwargs):
# --> 334         for chunk in self._connection._receive_response_body(**kwargs):
#     335             yield chunk
#     336 except BaseException as exc:
#     337     # If we get an exception while streaming the response,
#     338     # we want to close the response (and possibly the connection)
#     339     # before raising that exception.
#
# File ~/miniconda3/envs/financial_index/lib/python3.10/site-packages/httpcore/_sync/http11.py:203, in HTTP11Connection._receive_response_body(self, request)
#     200 timeout = timeouts.get("read", None)
#     202 while True:
# --> 203     event = self._receive_event(timeout=timeout)
#     204     if isinstance(event, h11.Data):
#     205         yield bytes(event.data)
#
# File ~/miniconda3/envs/financial_index/lib/python3.10/site-packages/httpcore/_sync/http11.py:217, in HTTP11Connection._receive_event(self, timeout)
#     214     event = self._h11_state.next_event()
#     216 if event is h11.NEED_DATA:
# --> 217     data = self._network_stream.read(
#     218         self.READ_NUM_BYTES, timeout=timeout
#     219     )
#     221     # If we feed this case through h11 we'll raise an exception like:
#     222     #
#     223     #     httpcore.RemoteProtocolError: can't handle event type
#    (...)
#     227     # perspective. Instead we handle this case distinctly and treat
#     228     # it as a ConnectError.
#     229     if data == b"" and self._h11_state.their_state == h11.SEND_RESPONSE:
#
# File ~/miniconda3/envs/financial_index/lib/python3.10/site-packages/httpcore/_backends/sync.py:128, in SyncStream.read(self, max_bytes, timeout)
#     126 with map_exceptions(exc_map):
#     127     self._sock.settimeout(timeout)
# --> 128     return self._sock.recv(max_bytes)
#
# KeyboardInterrupt:
